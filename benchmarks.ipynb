# %% [markdown]
# ## Testing Search Problem Algorithm
# In this notebook, we will test for different scenarios using the custom defined classes and solver algorithm in `search_problem.py`.
# We will set up the search problem varying the fiollowing parameters:
# * n_runway
# * max_delay
# * duration of disruption (by chaning the paramter `resume_hour` and/or `resume_min`)
# * Number of flights to consider (by changing the df passed into the `search_pronble` class)
#
# By default, the `resschedule_problem` class defines the problem with the following parameters:
# * n_runway = 1
# * disruption_dur = 60 (in minutes)
# * duration of time slot = 5 (in minutes)
# * Maximum delay permissible before a flight has to be diverted = 120

# %%
import pandas as pd 
import numpy as np
import itertools
# _________________________________
# search problem
class reschedule_problem:

    def __init__(self,df, n_runway = 1, disruption_dur = 60,\
                timeslot_dur = 5, max_delay = 120,divert_penalty = 1):
        # customized attributes of the problem
        self.df = df
        self.move = df['code']
        self.n_runway = n_runway
        self.resumetime = self.df.iloc[0,0] + pd.Timedelta(minutes = disruption_dur)
        self.hour = self.resumetime.hour
        self.min = self.resumetime.minute
        self.time_slot_duration = timeslot_dur
        self.max_delay = max_delay
        self.divert_penalty = divert_penalty # referenced in self.compute_util
        # parsing the attribute for more useful format
        self.date = self.df.loc[0,'time_sch'].day
        self.month = self.df.loc[0,'time_sch'].month
        self.year = self.df.loc[0,'time_sch'].year
        self.initial = pd.DataFrame(columns = ["time_new","util"], index= []) # to store the solution
        self.solution = None

    def actions(self, state:pd.DataFrame):
        """return a list of n_runway flight(s) that has/have is expected to land
        and is not assigned a time slot under the state; and one list of flight
        that has to be diverted"""
        # get the list of unassigned flight where the time_sch is (over)due under current time slot 
        assigned_flight = list([flight for flight in state.index])
        unassigned_flight = self.df.query("code not in @assigned_flight").copy()
        # subset the flights that are not in time yet / not diverted
        year, month, date, hour, min = self.parse_state_time(state)
        current_time = pd.to_datetime(f"{year} {month} {date} {hour}:{min}")
        min_time = pd.to_datetime(f"{year} {month} {date} {hour}:{min}") - pd.Timedelta(minutes = self.max_delay)
        # create boolean columns for subsetting diverted flights and those to schedule
        unassigned_flight['divert'] = unassigned_flight.apply(lambda flight: flight['time_sch'] < min_time,axis = 1)
        unassigned_flight['to_sch'] = unassigned_flight.apply(lambda flight: flight['time_sch'] <=current_time  ,axis = 1)

        # return the pd.Series of unassigned flight that has passed its schedule time
        flight_to_assign = unassigned_flight[unassigned_flight['to_sch'] & ~(unassigned_flight['divert'])]['code']
        # return the combination of flights (namely when n_runway > 1)
        flight_to_assign = [comb for n in range(1, self.n_runway+1) for comb in itertools.combinations(flight_to_assign, n)]
        # flight to divert
        flight_diverted = unassigned_flight[unassigned_flight['divert']]['code']

        return flight_to_assign, flight_diverted # pd.Series
        
    def parse_state_time(self,state:pd.DataFrame):
        """Use to get the value in the schedule and 
        parse the time of the next time slot"""
        if len(state) <=0: 
            year = self.year
            month = self.month
            date = self.date
            hour = self.hour
            min = self.min

        else:
            timestr = state['time_new'].iloc[-1] # get the time_sch
            year, month, date, time = timestr.split(" ")
            hour , min = time.split(":")
            # get the current time
            min = int(min)
            min += self.time_slot_duration
            if min // 60 <= 1:
                hour = int(hour) + min // 60
                min = min % 60
                if hour // 24 <= 1:
                    date = int(date) + hour // 24
                    hour = hour % 24
                
        return year, month, date, hour,min
    
    def result(self, state:pd.DataFrame, flight_diverted:list, flights:list):
        """return the state in a form of dictionary that is the result of a given move"""
        # parse the time data
        year, month, date, hour, min = self.parse_state_time(state)

        if len(flights) != 0:
            for fl in flights:
                time_sch = f"{year} {month} {date} {hour:02d}:{min:02d}"
                # get the utility
                util = self.compute_util(fl, year, month, date, hour, min)
                # print(f"Scheudling {flights} for {time_sch}")
                state.loc[fl] = [time_sch, util]
        elif not self.goal_test(state):
            # no flight can be assigned to the time slot
            time_sch = f"{year} {month} {date} {hour:02d}:{min:02d}"
            fl ='no flight to assign'
            state.loc[fl] = [time_sch, 0]
    
        # add the diverted flight into the state
        for fl in flight_diverted:
            util = self.compute_util(fl,1970, 0,0,0,0)
            state.loc[fl] = ["1970 01 01 00:00", util]
            # print(f"Diverting {flights}")

        # sort the state df by the new scheduled time
        state = state.sort_values("time_new")

        return state # pd.DataFrame
    
    def compute_util(self, flcode:str, year, month, date, hour, min):
        """Compute the utility of a given rescheduled flight. This is defined
        as the time difference between the original scheduled time and the 
        new scheduled time"""
        if flcode is None:
            return 0 
        elif year != 1970:
            time_sch_org = self.df.query("code == @flcode")['time_sch'] # type pd Series
            time_sch_new = pd.to_datetime(f"{year} {month} {date} {hour}:{min}")
            # compute the time delayed
            delay = time_sch_org - time_sch_new
            delay = delay.reset_index(drop = True)[0].total_seconds() / 60
            return delay
        elif year == 1970:
            # compute utility of diverted flight
            delay = - self.max_delay * self.divert_penalty
            return delay
    
    def utility(self, state:pd.DataFrame):
        """Compute aggregate utility of a given state"""
        agg_util = state['util'].sum()
        return agg_util
        
    def goal_test(self, state:pd.DataFrame):
        """return True if the state is terminal"""
        flight_assigned = [flight for flight in state.index] 
        if len(flight_assigned) == len(self.df):
        # !!! this is not a robust way since time slot can be none
            return True
        
    def solve(self, solver_algo):
        self.solution = solver_algo(self)   
        if self.solution is None:
            print("No solution is returned")
        
    def display(self):
        """ Display the self.solution that is of type pandas dataframe
        to compare the solution with the set up that we try to solve 
        """
        if self.solution is None:
            print("The problem has not been solved. Pass a solving algorithm to the .solve method")
            raise NotImplementedError
        elif type(self.solution) != pd.core.frame.DataFrame:
            print("""THe solution returned by the algorithm cannot be parsed because it is 
                  not of type pd.core.frame.DataFrame""")
        
        display_df = self.df.copy()
        display_df = pd.merge(self.df[['code','time_sch','pass_load']], self.solution, left_on= "code", right_index = True)
        display_df['time_new'] = pd.to_datetime(display_df['time_new'])
        display_df['time_dff'] = display_df.apply(lambda x: (x['time_sch'] - x['time_new']).total_seconds()/ 60,axis = 1 )
        display_df['time_dff'] = display_df['time_dff'].apply(lambda x: -x if x <= 0 else "diverted" )
        n_diverted = len(display_df.query("time_dff == 'diverted'"))
        print(f"{n_diverted} flights being diverted")
        return display_df
    
    def get_basemodel(self):
        given_data = self.df.copy()
        base_df = self.initial.copy()

        def parse_time_string(timestamp):
            year = timestamp.year
            month = timestamp.month
            day = timestamp.day
            hour = timestamp.hour
            minute = timestamp.minute
            return year, month, day, hour, minute

        year, month, date, hour, min = parse_time_string(self.resumetime)
        flights_in_slot = 0
        for _, flight in given_data.iterrows():
            time_sch_org = flight['time_sch'] # type pd Series
            time_sch_new = pd.to_datetime(f"{year}-{month}-{date} {hour}:{min}")
            if (time_sch_org - time_sch_new).total_seconds() < 0:
                time_sch = f"{year} {month} {date} {hour:02d}:{min:02d}"
                util = self.compute_util(flight['code'], year, month, date, hour, min)
            else: 
                time_sch = time_sch_org.strftime("%Y %m %d %H:%M")
                util = 0
            base_df.loc[flight['code']] = [time_sch, util]

            # Increment flight count and time slot only if the slot is full
            ori_min = min
            flights_in_slot += 1
            if flights_in_slot >= self.n_runway:
                min = ori_min + self.time_slot_duration
                flights_in_slot = 0
                if min >= 60:
                    hour += 1
                    min -= 60
                    if hour >= 24:
                        date += 1
                        hour -= 24
                ori_min = min

        display_df = self.df.copy()
        display_df = pd.merge(self.df[['code','time_sch','pass_load']], base_df, left_on= "code", right_index = True)
        display_df['time_new'] = pd.to_datetime(display_df['time_new'])
        display_df['time_dff'] = display_df.apply(lambda x: (x['time_sch'] - x['time_new']).total_seconds()/ 60,axis = 1 )
        display_df['time_dff'] = display_df['time_dff'].apply(lambda x: -x if x <= 0 else "diverted" )
        n_diverted = len(display_df.query("time_dff == 'diverted'"))
        print(f"{n_diverted} flights being diverted")
        return display_df

# __________________________
# search problem with alternative u function
class reschedule_custom_u(reschedule_problem):
    """inherit the properties of class reschedule_problem, but takes an additional
    argument`util_f`, a function that has two argment: delay and pass_load used to
    calculate the utility of the flights"""

    def __init__(self, df,util_f, n_runway = 1, disruption_dur = 60,
                timeslot_dur = 5, max_delay = 120, divert_penalty = 1):
        super().__init__(df, n_runway , disruption_dur,
                timeslot_dur, max_delay, divert_penalty)
        self.util_f = util_f


    def compute_util(self, flcode, year, month, date, hour, min):
        """Compute the utility of a given rescheduled flight. This is defined
        as the time difference between the original scheduled time and the 
        new scheduled time"""
        if flcode is None:
            return 0 
        elif year != 1970:
            time_sch_org = self.df.query("code == @flcode")['time_sch'] # type pd Series
            time_sch_new = pd.to_datetime(f"{year} {month} {date} {hour}:{min}")
            # compute the time delayed
            delay = time_sch_org - time_sch_new
            delay = delay.reset_index(drop = True)[0].total_seconds() / 60

        elif year == 1970:
            # compute utility of diverted flight
            delay = - self.max_delay * self.divert_penalty

        pass_load = self.df.query("code == @flcode")['pass_load'].values[0]
        util = self.util_f(delay, pass_load)

        return util

#____________________________
# search problem with alternative u function and discount on future U
class reschedule_custom_u_dis(reschedule_custom_u):
    """inherit the properties of `reschedule_custom_u`, taking an
    additional argument `dis_rate` which defines how much 
    we value the uncertainty of flights originally scheduled for later"""

    def __init__(self, df,util_f, n_runway = 1, disruption_dur = 60,
                timeslot_dur = 5, max_delay = 120, divert_penalty = 1, dis_rate = 1.05):
        super().__init__(df, util_f,n_runway , disruption_dur,
                timeslot_dur, max_delay, divert_penalty)
        self.dis_rate = dis_rate

    def compute_util(self, flcode, year, month, date, hour, min):
        """Compute the utility of a given rescheduled flight. This is defined
        as the time difference between the original scheduled time and the 
        new scheduled time"""
        
        if flcode is None:
            return 0 
        elif year != 1970:
            time_sch_org = self.df.query("code == @flcode")['time_sch'] # type pd Series
            time_sch_new = pd.to_datetime(f"{year} {month} {date} {hour}:{min}")
            # compute the time delayed
            delay = time_sch_org - time_sch_new
            delay = delay.reset_index(drop = True)[0].total_seconds() / 60

        elif year == 1970:
            # compute utility of diverted flight
            delay = - self.max_delay * self.divert_penalty

        pass_load = self.df.query("code == @flcode")['pass_load'].values[0]
        util = self.util_f(delay, pass_load)
        # compute discounted util
        time_sch_org = self.df.query("code == @flcode")['time_sch'] # type pd Series
        time_elapse = time_sch_org.values[0]  - self.resumetime
        time_elapse = time_elapse.total_seconds()
        time_period = time_elapse / 60 / self.time_slot_duration
        dis_util = util / (self.dis_rate ** time_period)

        return dis_util

# ____________________________
# node
class Node:
    """This takes a lot of refeneces to the AMINA class node"""
    def __init__(self, state,parent = None, action = None, path_cost = 0):
        self.state = state
        self.parent = parent
        self.action = action
        self.path_cost = path_cost
        self.depth = 0 
        if parent:
            self.depth = parent.depth + 1
    def __repr__(self):
        """define printing output of the class type"""
        return "<Node of depth {}>".format(self.depth)
    
    def __lt__(self, node):
        """Compare the depth of the nodes -- for use in 
        sorting the *frontier*"""
        return self.depth < node.depth
    
    def expand(self, problem):
        """reach the nodes reachable"""
        flight_to_assign, flight_diverted = problem.actions(self.state)
        if len(flight_to_assign) == 0:
            # when no flight can be assigned at the time slot
            flight_to_assign.append(list())
        return [self.child_node(problem, action, flight_diverted) 
                  for action in flight_to_assign]

    def child_node(self, problem,action, flight_diverted):
        """ Return a Node object representing the child node        
        """
        parent_state = self.state.copy()
        next_state = problem.result(parent_state, flight_diverted, action)
        # print(next_state)
        next_node = Node(next_state, parent=self, action = action, path_cost = problem.utility(next_state))
        return next_node # node object

    
# ____________________________________________
# bfs graph
def best_first_graph_search(problem):
    """Search the nodes with the lowest f scores first.
    You specify the function f(node) that you want to minimize; for example,
    if f is a heuristic estimate to the goal, then we have greedy best
    first search; if f is node.depth then we have breadth-first search.
    There is a subtlety: the line "f = memoize(f, 'f')" means that the f
    values will be cached on the nodes as they are computed. So after doing
    a best first search you can examine the f values of the path returned."""

    # adding first node
    node = Node(problem.initial)
    print(f"The airport resumed service at {problem.hour}:{problem.min:02d}")
    iterations = 1
    # applying the goal test when generating the node
    if problem.goal_test(node.state):
        return(iterations, node)

    # expand the frontier based on the priority queue
    # the current best candidate for extension
    frontier = list()
    frontier.append(tuple([node.path_cost,node ]))

    while frontier:
        if iterations % 1000 == 0:
            break_command = input("""1000 iterations operated. Continue or break? 
                                  Type in 'break' to break the loop, otherwise anything else""")
            if break_command is not None:
                if break_command.lower().strip == 'break':
                    break
        # get the next node in the frontier
        node = frontier.pop()[1]
        iterations +=1
        # applying the goal test when expanding the node
        if problem.goal_test(node.state):
            return node.state
        # for every child in the frontier
        for child in node.expand(problem): # child is a node
            frontier.append(tuple([int(child.path_cost),child]))
            frontier.sort(reverse = True) # order from lower cost to higher cost (absolute terms)

    print("No solution is returned by the solver algorithm")
    return None # otherwise return node.state
    
# ____________________________________________
# bfs graph
def breadth_first_search(problem):
    """Search the nodes with the lowest depth scores first.
    """
    # adding first node
    node = Node(problem.initial)
    print(f"The airport resumed service at {problem.hour}:{problem.min:02d}")
    iterations = 1
    # applying the goal test when generating the node
    if problem.goal_test(node.state):
        return(iterations, node)

    solutions = []
    # expand the frontier based on the priority queue
    # the current best candidate for extension
    frontier = list()
    frontier.append(tuple([node.depth,node ]))

    while frontier:
        # get the next node in the frontier
        node = frontier.pop()[1]
        # applying the goal test when expanding the node
        if problem.goal_test(node.state):
            # add the node to the list of dictionary
            solutions.append(tuple([node.path_cost,node]))
            print(f"A terminal state has been reached: total {len(solutions)} solutions")
        else:
            # for every child in the frontier
            for child in node.expand(problem): # child is a node
                print(f"Iteration: {iterations} at depth {child.depth}")
                print((f"Check if the depth is consistent withe the node state."))
                print(f"There should be {len(child.state)/problem.n_runway} timeslot iterated.")
                frontier.append(tuple([int(child.depth),child]))
                frontier.sort(reverse = True) # order from lower cost to higher cost (absolute terms)
                iterations+= 1
            
                if iterations % 1000 == 0:
                    msg = "1000 iterations processed. Continue or break? Type 'break' to break out of the loop"
                    command_input = input("Continue or break?")
                    try:
                        command_input = command_input.lower.strip() 
                    except:
                        command_input = None
                    if command_input != "break":
                        break

    # <return the solution from the list that has the maximum utility>
    # compute the utilityof all the solution yielded
    solutions.sort(reverse = True)
    # return the   
    return solutions

# %%
df = pd.read_csv("./data/21DEC2023_AMS_processed.csv", parse_dates = ['time_sch','time_act'])
df = df.sort_values("time_sch").reset_index(drop = True)
df.head()
# Out:
#              time_sch            time_act               code       dest  \
# 0 2023-12-21 00:10:00 2023-12-21 01:19:00  HV 6888 Transavia  Amsterdam
# 1 2023-12-21 00:25:00 2023-12-21 00:25:00  HV 5336 Transavia  Amsterdam
# 2 2023-12-21 01:00:00 2023-12-21 01:00:00  HV 6676 Transavia  Amsterdam
# 3 2023-12-21 05:45:00 2023-12-21 05:45:00         KL 590 KLM  Amsterdam
# 4 2023-12-21 05:50:00 2023-12-21 06:44:00         KL 810 KLM  Amsterdam
#
#               stat                   orig  pass_load  time_diff
# 0  BAGGAGE HANDLED        Reykjavik (KEF)        383     4140.0
# 1  BAGGAGE HANDLED  Sharm El Sheikh (SSH)        364        0.0
# 2  BAGGAGE HANDLED         Tenerife (TFS)        319        0.0
# 3  BAGGAGE HANDLED            Accra (ACC)        238        0.0
# 4  BAGGAGE HANDLED          Jakarta (CGK)        327     3240.0

# %% [markdown]
# ## Test 1: Uniform Cost Search
# In this first case, we will consider:
# * a dataframe of size 20
# * n_runway = 2
# * duration of disruption = 60
#
# We set up the problem using the `reschedule_problem` class which defines the path cost as the time delayed of the flight scheduled at the child node.

# %%
# subset the tail of the dataframe
df_subset = df.tail(20).reset_index(drop = True)
df_subset.head()
# Out:
#              time_sch            time_act                code       dest  \
# 0 2023-12-21 22:30:00 2023-12-21 22:30:00     OR 3802 TUI fly  Amsterdam
# 1 2023-12-21 22:35:00 2023-12-21 22:35:00   LH 2310 Lufthansa  Amsterdam
# 2 2023-12-21 22:35:00 2023-12-21 23:37:00         KL 1032 KLM  Amsterdam
# 3 2023-12-21 22:40:00 2023-12-22 01:10:00  AZ 118 ITA Airways  Amsterdam
# 4 2023-12-21 23:00:00 2023-12-21 23:00:00         KL 1706 KLM  Amsterdam
#
#               stat                   orig  pass_load  time_diff
# 0  BAGGAGE HANDLED         Tenerife (TFS)        236        0.0
# 1        CANCELLED           Munich (MUC)        339        0.0
# 2  BAGGAGE HANDLED  London Heathrow (LHR)        344     3720.0
# 3  BAGGAGE ON BELT     Milan Linate (LIN)        346   -77400.0
# 4        CANCELLED           Madrid (MAD)        316        0.0

# %%
# instantiate the problem
AMS21_n20_1 = reschedule_problem(df_subset, n_runway = 2)
# solve the problem
AMS21_n20_1.get_basemodel()
# Out:
# 0 flights being diverted
#                   code            time_sch  pass_load            time_new  \
# 0      OR 3802 TUI fly 2023-12-21 22:30:00        236 2023-12-21 23:30:00
# 1    LH 2310 Lufthansa 2023-12-21 22:35:00        339 2023-12-21 23:30:00
# 2          KL 1032 KLM 2023-12-21 22:35:00        344 2023-12-21 23:35:00
# 3   AZ 118 ITA Airways 2023-12-21 22:40:00        346 2023-12-21 23:35:00
# 4          KL 1706 KLM 2023-12-21 23:00:00        316 2023-12-21 23:40:00
# 5           KL 980 KLM 2023-12-21 23:00:00        186 2023-12-21 23:40:00
# 6          KL 1118 KLM 2023-12-21 23:00:00        263 2023-12-21 23:45:00
# 7          KL 1434 KLM 2023-12-21 23:00:00        343 2023-12-21 23:45:00
# 8          KL 1136 KLM 2023-12-21 23:05:00        263 2023-12-21 23:50:00
# 9    HV 5136 Transavia 2023-12-21 23:15:00        339 2023-12-21 23:50:00
# 10   HV 6886 Transavia 2023-12-21 23:15:00        386 2023-12-21 23:55:00
# 11         KL 1082 KLM 2023-12-21 23:20:00        375 2023-12-21 23:55:00
# 12   HV 5358 Transavia 2023-12-21 23:20:00        239 2023-12-22 00:00:00
# 13         KL 1834 KLM 2023-12-21 23:20:00        319 2023-12-22 00:00:00
# 14   HV 6114 Transavia 2023-12-21 23:25:00        300 2023-12-22 00:05:00
# 15         KL 1608 KLM 2023-12-21 23:25:00        309 2023-12-22 00:05:00
# 16   HV 5806 Transavia 2023-12-21 23:30:00        310 2023-12-22 00:10:00
# 17   HV 6902 Transavia 2023-12-21 23:40:00        316 2023-12-22 00:10:00
# 18   HV 5666 Transavia 2023-12-21 23:50:00        347 2023-12-22 00:15:00
# 19   HV 5218 Transavia 2023-12-21 23:55:00        304 2023-12-22 00:15:00
#
#     util  time_dff
# 0  -60.0      60.0
# 1  -55.0      55.0
# 2  -60.0      60.0
# 3  -55.0      55.0
# 4  -40.0      40.0
# 5  -40.0      40.0
# 6  -45.0      45.0
# 7  -45.0      45.0
# 8  -45.0      45.0
# 9  -35.0      35.0
# 10 -40.0      40.0
# 11 -35.0      35.0
# 12 -40.0      40.0
# 13 -40.0      40.0
# 14 -40.0      40.0
# 15 -40.0      40.0
# 16 -40.0      40.0
# 17 -30.0      30.0
# 18 -25.0      25.0
# 19 -20.0      20.0

# %%
AMS21_n20_1.solve(best_first_graph_search)
AMS21_n20_1.display()
# Out:
# The airport resumed service at 23:30
# 0 flights being diverted
#                   code            time_sch  pass_load            time_new  \
# 0      OR 3802 TUI fly 2023-12-21 22:30:00        236 2023-12-21 23:30:00
# 1    LH 2310 Lufthansa 2023-12-21 22:35:00        339 2023-12-21 23:35:00
# 2          KL 1032 KLM 2023-12-21 22:35:00        344 2023-12-21 23:30:00
# 3   AZ 118 ITA Airways 2023-12-21 22:40:00        346 2023-12-21 23:35:00
# 4          KL 1706 KLM 2023-12-21 23:00:00        316 2023-12-21 23:45:00
# 5           KL 980 KLM 2023-12-21 23:00:00        186 2023-12-21 23:45:00
# 6          KL 1118 KLM 2023-12-21 23:00:00        263 2023-12-21 23:40:00
# 7          KL 1434 KLM 2023-12-21 23:00:00        343 2023-12-21 23:40:00
# 8          KL 1136 KLM 2023-12-21 23:05:00        263 2023-12-21 23:50:00
# 9    HV 5136 Transavia 2023-12-21 23:15:00        339 2023-12-21 23:55:00
# 10   HV 6886 Transavia 2023-12-21 23:15:00        386 2023-12-21 23:50:00
# 11         KL 1082 KLM 2023-12-21 23:20:00        375 2023-12-22 00:00:00
# 12   HV 5358 Transavia 2023-12-21 23:20:00        239 2023-12-22 00:00:00
# 13         KL 1834 KLM 2023-12-21 23:20:00        319 2023-12-21 23:55:00
# 14   HV 6114 Transavia 2023-12-21 23:25:00        300 2023-12-22 00:05:00
# 15         KL 1608 KLM 2023-12-21 23:25:00        309 2023-12-22 00:05:00
# 16   HV 5806 Transavia 2023-12-21 23:30:00        310 2023-12-22 00:10:00
# 17   HV 6902 Transavia 2023-12-21 23:40:00        316 2023-12-22 00:10:00
# 18   HV 5666 Transavia 2023-12-21 23:50:00        347 2023-12-22 00:15:00
# 19   HV 5218 Transavia 2023-12-21 23:55:00        304 2023-12-22 00:15:00
#
#     util  time_dff
# 0  -60.0      60.0
# 1  -60.0      60.0
# 2  -55.0      55.0
# 3  -55.0      55.0
# 4  -45.0      45.0
# 5  -45.0      45.0
# 6  -40.0      40.0
# 7  -40.0      40.0
# 8  -45.0      45.0
# 9  -40.0      40.0
# 10 -35.0      35.0
# 11 -40.0      40.0
# 12 -40.0      40.0
# 13 -35.0      35.0
# 14 -40.0      40.0
# 15 -40.0      40.0
# 16 -40.0      40.0
# 17 -30.0      30.0
# 18 -25.0      25.0
# 19 -20.0      20.0

# %% [markdown]
# ## Test 2 Breadth-First Search
# Here we use the breadth first tree search, assuming that the path cost is the depth of the node.
# We can see from this particularly case, there is a significant increase of the runtime.
#
# In this section, we set up the problem for rescheduling 6 flights only because breadth-first search, in general, has a high time complexity as the algorithm seeks to conduct a complete search of all possible terminal state. As such, we also reduce the time of airport disruption to 20 min.

# %%
# subset
df_subset_2 = df.tail(6).reset_index(drop = True)
# instantiate the problem
AMS21_n6_2 = reschedule_problem(df_subset_2, n_runway = 2,max_delay=120, disruption_dur= 20)
# solve the problem
AMS21_n6_2.solve(breadth_first_search)
# return the solution
breadth_fs_sol_2 = AMS21_n6_2.solution
# Out:
# The airport resumed service at 23:45
# Iteration: 1 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 0.5 timeslot iterated.
# Iteration: 2 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 0.5 timeslot iterated.
# Iteration: 3 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 0.5 timeslot iterated.
# Iteration: 4 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 0.5 timeslot iterated.
# Iteration: 5 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 6 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 7 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 8 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 9 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 10 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 11 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 12 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 13 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 14 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 15 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 16 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 17 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 18 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 19 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 20 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 21 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 22 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 23 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 24 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 25 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 26 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 27 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 28 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 29 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 30 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 31 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 32 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 33 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 34 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 35 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 36 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 37 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 38 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 39 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 40 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 41 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 42 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 43 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 44 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 45 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 46 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 47 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 48 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 49 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 50 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 51 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 52 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 53 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 54 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 55 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 56 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 57 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 58 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 59 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 60 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 61 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 62 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 63 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 64 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 65 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 66 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 67 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 68 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 69 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 70 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 71 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 72 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 73 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 74 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 75 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 76 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 77 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 78 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 79 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 80 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 81 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 82 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 83 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 84 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 85 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 86 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 87 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 88 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 89 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 90 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 91 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 92 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 93 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 94 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 95 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 96 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 97 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 98 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 99 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 100 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 101 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 102 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 103 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 104 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 105 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 106 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 107 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 108 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 109 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 110 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 111 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 112 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 113 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 114 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 115 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 116 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 117 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 118 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 119 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 120 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 121 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 122 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 123 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 124 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 125 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 126 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 127 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 128 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 129 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 130 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 131 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 132 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 133 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 134 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 135 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 136 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 137 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 138 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 139 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 140 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 141 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 142 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 143 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 144 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 145 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 146 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 147 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 148 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 149 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 150 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 151 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 152 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 153 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 154 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 155 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 156 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 157 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 158 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 159 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 160 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 161 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 162 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 163 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 164 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 165 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 166 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 167 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 168 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 169 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 170 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 171 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 172 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 173 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 174 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 175 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 176 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 177 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 178 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 179 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 180 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 181 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 182 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 183 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 184 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 185 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 186 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 187 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 188 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 189 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 190 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 191 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 192 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 193 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 194 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 195 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 196 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 197 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 198 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 199 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 200 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 201 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 202 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 203 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 204 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 205 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 206 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 207 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 208 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 209 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 210 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 211 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 212 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 213 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 214 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 215 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 216 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 217 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 218 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 219 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 220 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 221 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 222 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 223 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 224 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 225 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 226 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 227 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 228 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 229 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 230 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 231 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 232 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 233 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 234 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 235 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 236 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 237 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 238 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 239 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 240 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 241 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 242 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 243 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 244 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 245 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 246 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 247 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 248 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 249 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 250 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 251 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 252 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 253 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 254 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 255 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 256 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 257 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 258 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 259 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 260 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 261 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 262 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 263 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 264 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 265 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 266 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 267 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 268 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 269 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 270 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 271 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 272 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 273 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 274 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 275 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 276 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 277 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 278 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 279 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 280 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 281 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 282 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 283 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 284 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 285 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 286 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 287 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 288 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 289 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 290 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 291 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 292 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 293 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 294 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 295 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 296 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 297 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 298 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 299 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 300 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 301 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 302 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 303 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 304 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 305 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 306 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 307 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 308 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 309 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 310 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 311 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 312 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 313 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 314 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 315 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 316 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 317 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 318 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 319 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 320 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 321 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 322 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 323 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 324 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 325 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 326 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 327 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 328 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 329 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 330 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 331 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 332 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 333 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 334 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 335 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 336 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 337 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 338 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 339 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 340 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 341 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 342 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 343 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 344 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 345 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 346 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 347 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 348 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 349 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 350 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 351 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 352 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 353 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 354 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 355 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 356 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 357 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 358 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 359 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 360 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 361 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 362 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 363 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 364 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 365 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 366 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 367 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 368 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 369 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 370 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 371 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 372 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 373 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 374 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 375 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 376 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 377 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 378 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 379 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 380 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 381 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 382 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 383 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 384 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 1.5 timeslot iterated.
# Iteration: 385 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 386 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 387 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 388 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 389 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 390 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 391 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 392 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 393 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 394 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 395 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 396 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 397 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 398 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.5 timeslot iterated.
# Iteration: 399 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 400 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 401 at depth 3
# ...
# A terminal state has been reached: total 1328 solutions
# A terminal state has been reached: total 1329 solutions
# A terminal state has been reached: total 1330 solutions
# A terminal state has been reached: total 1331 solutions
# A terminal state has been reached: total 1332 solutions
# A terminal state has been reached: total 1333 solutions
# A terminal state has been reached: total 1334 solutions
# A terminal state has been reached: total 1335 solutions
# A terminal state has been reached: total 1336 solutions
# A terminal state has been reached: total 1337 solutions
# A terminal state has been reached: total 1338 solutions
# A terminal state has been reached: total 1339 solutions
# A terminal state has been reached: total 1340 solutions
# A terminal state has been reached: total 1341 solutions
# A terminal state has been reached: total 1342 solutions
# A terminal state has been reached: total 1343 solutions
# A terminal state has been reached: total 1344 solutions
# A terminal state has been reached: total 1345 solutions
# A terminal state has been reached: total 1346 solutions
# A terminal state has been reached: total 1347 solutions
# A terminal state has been reached: total 1348 solutions
# A terminal state has been reached: total 1349 solutions
# A terminal state has been reached: total 1350 solutions
# A terminal state has been reached: total 1351 solutions
# A terminal state has been reached: total 1352 solutions
# A terminal state has been reached: total 1353 solutions
# A terminal state has been reached: total 1354 solutions
# A terminal state has been reached: total 1355 solutions
# A terminal state has been reached: total 1356 solutions
# A terminal state has been reached: total 1357 solutions
# A terminal state has been reached: total 1358 solutions
# A terminal state has been reached: total 1359 solutions
# A terminal state has been reached: total 1360 solutions
# A terminal state has been reached: total 1361 solutions
# A terminal state has been reached: total 1362 solutions
# A terminal state has been reached: total 1363 solutions
# A terminal state has been reached: total 1364 solutions
# A terminal state has been reached: total 1365 solutions
# A terminal state has been reached: total 1366 solutions
# A terminal state has been reached: total 1367 solutions
# A terminal state has been reached: total 1368 solutions
# A terminal state has been reached: total 1369 solutions
# A terminal state has been reached: total 1370 solutions
# A terminal state has been reached: total 1371 solutions
# A terminal state has been reached: total 1372 solutions
# A terminal state has been reached: total 1373 solutions
# A terminal state has been reached: total 1374 solutions
# A terminal state has been reached: total 1375 solutions
# A terminal state has been reached: total 1376 solutions
# A terminal state has been reached: total 1377 solutions
# A terminal state has been reached: total 1378 solutions
# A terminal state has been reached: total 1379 solutions
# A terminal state has been reached: total 1380 solutions
# A terminal state has been reached: total 1381 solutions
# A terminal state has been reached: total 1382 solutions
# A terminal state has been reached: total 1383 solutions
# A terminal state has been reached: total 1384 solutions
# A terminal state has been reached: total 1385 solutions
# A terminal state has been reached: total 1386 solutions
# A terminal state has been reached: total 1387 solutions
# A terminal state has been reached: total 1388 solutions
# A terminal state has been reached: total 1389 solutions
# A terminal state has been reached: total 1390 solutions
# A terminal state has been reached: total 1391 solutions
# A terminal state has been reached: total 1392 solutions
# A terminal state has been reached: total 1393 solutions
# A terminal state has been reached: total 1394 solutions
# A terminal state has been reached: total 1395 solutions
# A terminal state has been reached: total 1396 solutions
# A terminal state has been reached: total 1397 solutions
# A terminal state has been reached: total 1398 solutions
# A terminal state has been reached: total 1399 solutions
# A terminal state has been reached: total 1400 solutions
# A terminal state has been reached: total 1401 solutions
# A terminal state has been reached: total 1402 solutions
# A terminal state has been reached: total 1403 solutions
# A terminal state has been reached: total 1404 solutions
# A terminal state has been reached: total 1405 solutions
# A terminal state has been reached: total 1406 solutions
# A terminal state has been reached: total 1407 solutions
# A terminal state has been reached: total 1408 solutions
# A terminal state has been reached: total 1409 solutions
# A terminal state has been reached: total 1410 solutions
# A terminal state has been reached: total 1411 solutions
# A terminal state has been reached: total 1412 solutions
# A terminal state has been reached: total 1413 solutions
# A terminal state has been reached: total 1414 solutions
# A terminal state has been reached: total 1415 solutions
# A terminal state has been reached: total 1416 solutions
# A terminal state has been reached: total 1417 solutions
# A terminal state has been reached: total 1418 solutions
# A terminal state has been reached: total 1419 solutions
# A terminal state has been reached: total 1420 solutions
# A terminal state has been reached: total 1421 solutions
# A terminal state has been reached: total 1422 solutions
# A terminal state has been reached: total 1423 solutions
# A terminal state has been reached: total 1424 solutions
# A terminal state has been reached: total 1425 solutions
# A terminal state has been reached: total 1426 solutions
# A terminal state has been reached: total 1427 solutions
# A terminal state has been reached: total 1428 solutions
# A terminal state has been reached: total 1429 solutions
# A terminal state has been reached: total 1430 solutions
# A terminal state has been reached: total 1431 solutions
# A terminal state has been reached: total 1432 solutions
# A terminal state has been reached: total 1433 solutions
# A terminal state has been reached: total 1434 solutions
# A terminal state has been reached: total 1435 solutions
# A terminal state has been reached: total 1436 solutions
# A terminal state has been reached: total 1437 solutions
# A terminal state has been reached: total 1438 solutions
# A terminal state has been reached: total 1439 solutions
# A terminal state has been reached: total 1440 solutions
# A terminal state has been reached: total 1441 solutions
# A terminal state has been reached: total 1442 solutions
# A terminal state has been reached: total 1443 solutions
# A terminal state has been reached: total 1444 solutions
# A terminal state has been reached: total 1445 solutions
# A terminal state has been reached: total 1446 solutions
# A terminal state has been reached: total 1447 solutions
# A terminal state has been reached: total 1448 solutions
# A terminal state has been reached: total 1449 solutions
# A terminal state has been reached: total 1450 solutions
# A terminal state has been reached: total 1451 solutions
# A terminal state has been reached: total 1452 solutions
# A terminal state has been reached: total 1453 solutions
# A terminal state has been reached: total 1454 solutions
# A terminal state has been reached: total 1455 solutions
# A terminal state has been reached: total 1456 solutions
# A terminal state has been reached: total 1457 solutions
# A terminal state has been reached: total 1458 solutions
# A terminal state has been reached: total 1459 solutions
# A terminal state has been reached: total 1460 solutions
# A terminal state has been reached: total 1461 solutions
# A terminal state has been reached: total 1462 solutions
# A terminal state has been reached: total 1463 solutions
# A terminal state has been reached: total 1464 solutions
# A terminal state has been reached: total 1465 solutions
# A terminal state has been reached: total 1466 solutions
# A terminal state has been reached: total 1467 solutions
# A terminal state has been reached: total 1468 solutions
# A terminal state has been reached: total 1469 solutions
# A terminal state has been reached: total 1470 solutions
# A terminal state has been reached: total 1471 solutions
# A terminal state has been reached: total 1472 solutions
# A terminal state has been reached: total 1473 solutions
# A terminal state has been reached: total 1474 solutions
# A terminal state has been reached: total 1475 solutions
# A terminal state has been reached: total 1476 solutions
# A terminal state has been reached: total 1477 solutions
# A terminal state has been reached: total 1478 solutions
# A terminal state has been reached: total 1479 solutions
# A terminal state has been reached: total 1480 solutions
# A terminal state has been reached: total 1481 solutions
# A terminal state has been reached: total 1482 solutions
# A terminal state has been reached: total 1483 solutions
# A terminal state has been reached: total 1484 solutions
# A terminal state has been reached: total 1485 solutions
# A terminal state has been reached: total 1486 solutions
# A terminal state has been reached: total 1487 solutions
# A terminal state has been reached: total 1488 solutions
# A terminal state has been reached: total 1489 solutions
# A terminal state has been reached: total 1490 solutions
# A terminal state has been reached: total 1491 solutions
# A terminal state has been reached: total 1492 solutions
# A terminal state has been reached: total 1493 solutions
# A terminal state has been reached: total 1494 solutions
# A terminal state has been reached: total 1495 solutions
# A terminal state has been reached: total 1496 solutions
# A terminal state has been reached: total 1497 solutions
# A terminal state has been reached: total 1498 solutions
# A terminal state has been reached: total 1499 solutions
# A terminal state has been reached: total 1500 solutions
# A terminal state has been reached: total 1501 solutions
# A terminal state has been reached: total 1502 solutions
# A terminal state has been reached: total 1503 solutions
# A terminal state has been reached: total 1504 solutions
# A terminal state has been reached: total 1505 solutions
# A terminal state has been reached: total 1506 solutions
# A terminal state has been reached: total 1507 solutions
# A terminal state has been reached: total 1508 solutions
# A terminal state has been reached: total 1509 solutions
# A terminal state has been reached: total 1510 solutions
# A terminal state has been reached: total 1511 solutions
# A terminal state has been reached: total 1512 solutions
# A terminal state has been reached: total 1513 solutions
# A terminal state has been reached: total 1514 solutions
# A terminal state has been reached: total 1515 solutions
# A terminal state has been reached: total 1516 solutions
# A terminal state has been reached: total 1517 solutions
# A terminal state has been reached: total 1518 solutions
# A terminal state has been reached: total 1519 solutions
# A terminal state has been reached: total 1520 solutions
# A terminal state has been reached: total 1521 solutions
# A terminal state has been reached: total 1522 solutions
# A terminal state has been reached: total 1523 solutions
# A terminal state has been reached: total 1524 solutions
# A terminal state has been reached: total 1525 solutions
# A terminal state has been reached: total 1526 solutions
# A terminal state has been reached: total 1527 solutions
# A terminal state has been reached: total 1528 solutions
# A terminal state has been reached: total 1529 solutions
# A terminal state has been reached: total 1530 solutions
# A terminal state has been reached: total 1531 solutions
# A terminal state has been reached: total 1532 solutions
# A terminal state has been reached: total 1533 solutions
# A terminal state has been reached: total 1534 solutions
# A terminal state has been reached: total 1535 solutions
# A terminal state has been reached: total 1536 solutions
# A terminal state has been reached: total 1537 solutions
# A terminal state has been reached: total 1538 solutions
# A terminal state has been reached: total 1539 solutions
# A terminal state has been reached: total 1540 solutions
# A terminal state has been reached: total 1541 solutions
# A terminal state has been reached: total 1542 solutions
# A terminal state has been reached: total 1543 solutions
# A terminal state has been reached: total 1544 solutions
# A terminal state has been reached: total 1545 solutions
# A terminal state has been reached: total 1546 solutions
# A terminal state has been reached: total 1547 solutions
# A terminal state has been reached: total 1548 solutions
# A terminal state has been reached: total 1549 solutions
# A terminal state has been reached: total 1550 solutions
# A terminal state has been reached: total 1551 solutions
# A terminal state has been reached: total 1552 solutions
# A terminal state has been reached: total 1553 solutions
# A terminal state has been reached: total 1554 solutions
# A terminal state has been reached: total 1555 solutions
# A terminal state has been reached: total 1556 solutions
# A terminal state has been reached: total 1557 solutions
# A terminal state has been reached: total 1558 solutions
# A terminal state has been reached: total 1559 solutions
# A terminal state has been reached: total 1560 solutions
# A terminal state has been reached: total 1561 solutions
# A terminal state has been reached: total 1562 solutions
# A terminal state has been reached: total 1563 solutions
# A terminal state has been reached: total 1564 solutions
# A terminal state has been reached: total 1565 solutions
# A terminal state has been reached: total 1566 solutions
# A terminal state has been reached: total 1567 solutions
# A terminal state has been reached: total 1568 solutions
# A terminal state has been reached: total 1569 solutions
# A terminal state has been reached: total 1570 solutions
# A terminal state has been reached: total 1571 solutions
# A terminal state has been reached: total 1572 solutions
# A terminal state has been reached: total 1573 solutions
# A terminal state has been reached: total 1574 solutions
# A terminal state has been reached: total 1575 solutions
# A terminal state has been reached: total 1576 solutions
# A terminal state has been reached: total 1577 solutions
# A terminal state has been reached: total 1578 solutions
# A terminal state has been reached: total 1579 solutions
# A terminal state has been reached: total 1580 solutions
# A terminal state has been reached: total 1581 solutions
# A terminal state has been reached: total 1582 solutions
# A terminal state has been reached: total 1583 solutions
# A terminal state has been reached: total 1584 solutions
# A terminal state has been reached: total 1585 solutions
# A terminal state has been reached: total 1586 solutions
# A terminal state has been reached: total 1587 solutions
# A terminal state has been reached: total 1588 solutions
# A terminal state has been reached: total 1589 solutions
# A terminal state has been reached: total 1590 solutions
# A terminal state has been reached: total 1591 solutions
# A terminal state has been reached: total 1592 solutions
# A terminal state has been reached: total 1593 solutions
# A terminal state has been reached: total 1594 solutions
# A terminal state has been reached: total 1595 solutions
# A terminal state has been reached: total 1596 solutions
# A terminal state has been reached: total 1597 solutions
# A terminal state has been reached: total 1598 solutions
# A terminal state has been reached: total 1599 solutions
# A terminal state has been reached: total 1600 solutions
# A terminal state has been reached: total 1601 solutions
# A terminal state has been reached: total 1602 solutions
# A terminal state has been reached: total 1603 solutions
# A terminal state has been reached: total 1604 solutions
# A terminal state has been reached: total 1605 solutions
# A terminal state has been reached: total 1606 solutions
# A terminal state has been reached: total 1607 solutions
# A terminal state has been reached: total 1608 solutions
# A terminal state has been reached: total 1609 solutions
# A terminal state has been reached: total 1610 solutions
# A terminal state has been reached: total 1611 solutions
# A terminal state has been reached: total 1612 solutions

# %%
# inspect the result
n_sol =len(breadth_fs_sol_2)
print(f"There are in total {n_sol} number of solution.")
# unzip the solution list
max_util = breadth_fs_sol_2[0][0]
sol_max_score = [node for util, node in breadth_fs_sol_2 if util == max_util]
print(f"The maximum utility of all solution is {max_util}, with {len(sol_max_score)} yielding this utility")
# Out:
# There are in total 1612 number of solution.
# The maximum utility of all solution is -75.0, with 18 yielding this utility

# %% [markdown]
# As expected, the algorithm takes a long time before it returns a solution. With this reduced case of rescheduling only 6 flights, it takes more than 15 seconds for the algorithm to complete.
# It returns all 1614 solutions, out of which 12 share the same utility of -80, that is the maximum utility across all the solutions.
#
# In fact, the time complexity for the breath first search algorithm put a lot of stress on the computation power and it is simply not feasible to rely on the algorithm this resolve the scheduling issue when a lot of flights have to be rescheduled: Empirically, rescheduling 10 flights takes more than **20 min**. Due to the limitation of the computational power, we will not be discussing such case in this project.
#
# Nonetheless, this highlight a major drawback of the application of best-first search in a real-world scenario:
# * If there is not more flights to reschedule, rescheudling the flights with a simple rule of assigning the earliest slot to the earlist plan would not yield a lot of lost in utility.
# * If there is more flights to reschedule, then the algorith simply cannot return a solution within a feasible time constraint before an airport has to return to operation.

# %% [markdown]
# ## Test 3 Model Comparison
# In this section, let's compare the breath-first search algorith with the uniform-cost search. As discussed in the section above, breadth-first search requires a lot of computation. Hence, we will limit the size of our problem to rescheduling only 5 flights in thhis section for a fair comparison of the solution they return.
#
# ### Breadth-First Search

# %%
# subset
df_subset_3 = df.tail(6).reset_index(drop = True)
# instantiate the problem
AMS21_n5_3 = reschedule_problem(df_subset_3, n_runway = 1,max_delay=120, disruption_dur= 15)
# solve the problem
AMS21_n5_3.solve(breadth_first_search)
# the breadth first search returns a list of solution(s)
breadth_fs_sol_3 = AMS21_n5_3.solution
# Out:
# The airport resumed service at 23:40
# Iteration: 1 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 2 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 3 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 4 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 5 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 6 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 7 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 8 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 9 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 10 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 11 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 12 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 13 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 14 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 15 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 16 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 17 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 18 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 19 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 20 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 21 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 22 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 23 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 24 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 25 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 26 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 27 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 28 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 29 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 30 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 31 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 32 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 33 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 34 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 35 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 36 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 37 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 38 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 39 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 40 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 41 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 42 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 43 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 44 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 45 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 46 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 47 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 48 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 49 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 50 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 51 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 52 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 53 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 54 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 55 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 56 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 57 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 58 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 59 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 60 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 61 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 62 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 63 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 64 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 65 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 66 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 67 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 68 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 69 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 70 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 71 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 72 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 73 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 74 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 75 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 76 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 77 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 78 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 79 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 80 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 81 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 82 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 83 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 84 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 85 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 86 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 87 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 88 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 89 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 90 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 91 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 92 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 93 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 94 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 95 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 96 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 97 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 98 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 99 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 100 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 101 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 102 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 103 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 104 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 105 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 106 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 107 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 108 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 109 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 110 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 111 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 112 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 113 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 114 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 115 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 116 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 117 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 118 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 119 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 120 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 121 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 122 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 123 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 124 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 125 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 126 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 127 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 128 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 129 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 130 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 131 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 132 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 133 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 134 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 135 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 136 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 137 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 138 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 139 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 140 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 141 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 142 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 143 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 144 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 145 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 146 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 147 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 148 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 149 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 150 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 151 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 152 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 153 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 154 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 155 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 156 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 157 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 158 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 159 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 160 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 161 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 162 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 163 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 164 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 165 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 166 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 167 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 168 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 169 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 170 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 171 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 172 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 173 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 174 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 175 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 176 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 177 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 178 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 179 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 180 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 181 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 182 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 183 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 184 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 185 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 186 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 187 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 188 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 189 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 190 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 191 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 192 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 193 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 194 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 195 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 196 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 197 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 198 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 199 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 200 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 201 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 202 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 203 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 204 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 205 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 206 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 207 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 208 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 209 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 210 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 211 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 212 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 213 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 214 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 215 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 216 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 217 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 218 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 219 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 220 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 221 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 222 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 223 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 224 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 225 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 226 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 227 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 228 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 229 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 230 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 231 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 232 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 233 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 234 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 235 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 236 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 237 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 238 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 239 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 240 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 241 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 242 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 243 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 244 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 245 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 246 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 247 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 248 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 249 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 250 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 251 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 252 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 253 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 254 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 255 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 256 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 257 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 258 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 259 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 260 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 261 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 262 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 263 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 264 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 265 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 266 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 267 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 268 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 269 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 270 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 271 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 272 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 273 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 274 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 275 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 276 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 277 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 278 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 279 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 280 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 281 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 282 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 283 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 284 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 285 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 286 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 287 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 288 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 289 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 290 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 291 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 292 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 293 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 294 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 295 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 296 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 297 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 298 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 299 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 300 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 301 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 302 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 303 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 304 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 305 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 306 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 307 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 308 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 309 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 310 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 311 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 312 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 313 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 314 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 315 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 316 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 317 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 318 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 319 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 320 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 321 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 322 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 323 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 324 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 325 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 326 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 327 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 328 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 329 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 330 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 331 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 332 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 333 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 334 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 335 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 336 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 337 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 338 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 339 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 340 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 341 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 342 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 343 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 344 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 345 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 346 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 347 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 348 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 349 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 350 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 351 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 352 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 353 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 354 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 355 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 356 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 357 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 358 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 359 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 360 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 361 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 362 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 363 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 364 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 365 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 366 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 367 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 368 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 369 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 370 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 371 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 372 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 373 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 374 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 375 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 376 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 377 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 378 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 379 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 380 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 381 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 382 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 383 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 384 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 385 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 386 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 387 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 388 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 389 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 390 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 391 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 392 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 393 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 394 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 395 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 396 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 397 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 398 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 399 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 400 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 401 at depth 6
# ...
# Iteration: 558 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 559 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 560 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 561 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 562 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 563 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 564 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 565 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 566 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 567 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 568 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 569 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 570 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 571 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 572 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 573 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 574 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 575 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 576 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 577 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 578 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 579 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 580 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 581 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 582 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 583 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 584 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 585 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 586 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 587 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 588 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 589 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 590 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 591 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 592 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# A terminal state has been reached: total 1 solutions
# A terminal state has been reached: total 2 solutions
# A terminal state has been reached: total 3 solutions
# A terminal state has been reached: total 4 solutions
# A terminal state has been reached: total 5 solutions
# A terminal state has been reached: total 6 solutions
# A terminal state has been reached: total 7 solutions
# A terminal state has been reached: total 8 solutions
# A terminal state has been reached: total 9 solutions
# A terminal state has been reached: total 10 solutions
# A terminal state has been reached: total 11 solutions
# A terminal state has been reached: total 12 solutions
# A terminal state has been reached: total 13 solutions
# A terminal state has been reached: total 14 solutions
# A terminal state has been reached: total 15 solutions
# A terminal state has been reached: total 16 solutions
# A terminal state has been reached: total 17 solutions
# A terminal state has been reached: total 18 solutions
# A terminal state has been reached: total 19 solutions
# A terminal state has been reached: total 20 solutions
# A terminal state has been reached: total 21 solutions
# A terminal state has been reached: total 22 solutions
# A terminal state has been reached: total 23 solutions
# A terminal state has been reached: total 24 solutions
# A terminal state has been reached: total 25 solutions
# A terminal state has been reached: total 26 solutions
# A terminal state has been reached: total 27 solutions
# A terminal state has been reached: total 28 solutions
# A terminal state has been reached: total 29 solutions
# A terminal state has been reached: total 30 solutions
# A terminal state has been reached: total 31 solutions
# A terminal state has been reached: total 32 solutions
# A terminal state has been reached: total 33 solutions
# A terminal state has been reached: total 34 solutions
# A terminal state has been reached: total 35 solutions
# A terminal state has been reached: total 36 solutions
# A terminal state has been reached: total 37 solutions
# A terminal state has been reached: total 38 solutions
# A terminal state has been reached: total 39 solutions
# A terminal state has been reached: total 40 solutions
# A terminal state has been reached: total 41 solutions
# A terminal state has been reached: total 42 solutions
# A terminal state has been reached: total 43 solutions
# A terminal state has been reached: total 44 solutions
# A terminal state has been reached: total 45 solutions
# A terminal state has been reached: total 46 solutions
# A terminal state has been reached: total 47 solutions
# A terminal state has been reached: total 48 solutions
# A terminal state has been reached: total 49 solutions
# A terminal state has been reached: total 50 solutions
# A terminal state has been reached: total 51 solutions
# A terminal state has been reached: total 52 solutions
# A terminal state has been reached: total 53 solutions
# A terminal state has been reached: total 54 solutions
# A terminal state has been reached: total 55 solutions
# A terminal state has been reached: total 56 solutions
# A terminal state has been reached: total 57 solutions
# A terminal state has been reached: total 58 solutions
# A terminal state has been reached: total 59 solutions
# A terminal state has been reached: total 60 solutions
# A terminal state has been reached: total 61 solutions
# A terminal state has been reached: total 62 solutions
# A terminal state has been reached: total 63 solutions
# A terminal state has been reached: total 64 solutions
# A terminal state has been reached: total 65 solutions
# A terminal state has been reached: total 66 solutions
# A terminal state has been reached: total 67 solutions
# A terminal state has been reached: total 68 solutions
# A terminal state has been reached: total 69 solutions
# A terminal state has been reached: total 70 solutions
# A terminal state has been reached: total 71 solutions
# A terminal state has been reached: total 72 solutions
# A terminal state has been reached: total 73 solutions
# A terminal state has been reached: total 74 solutions
# A terminal state has been reached: total 75 solutions
# A terminal state has been reached: total 76 solutions
# A terminal state has been reached: total 77 solutions
# A terminal state has been reached: total 78 solutions
# A terminal state has been reached: total 79 solutions
# A terminal state has been reached: total 80 solutions
# A terminal state has been reached: total 81 solutions
# A terminal state has been reached: total 82 solutions
# A terminal state has been reached: total 83 solutions
# A terminal state has been reached: total 84 solutions
# A terminal state has been reached: total 85 solutions
# A terminal state has been reached: total 86 solutions
# A terminal state has been reached: total 87 solutions
# A terminal state has been reached: total 88 solutions
# A terminal state has been reached: total 89 solutions
# A terminal state has been reached: total 90 solutions
# A terminal state has been reached: total 91 solutions
# A terminal state has been reached: total 92 solutions
# A terminal state has been reached: total 93 solutions
# A terminal state has been reached: total 94 solutions
# A terminal state has been reached: total 95 solutions
# A terminal state has been reached: total 96 solutions
# A terminal state has been reached: total 97 solutions
# A terminal state has been reached: total 98 solutions
# A terminal state has been reached: total 99 solutions
# A terminal state has been reached: total 100 solutions
# A terminal state has been reached: total 101 solutions
# A terminal state has been reached: total 102 solutions
# A terminal state has been reached: total 103 solutions
# A terminal state has been reached: total 104 solutions
# A terminal state has been reached: total 105 solutions
# A terminal state has been reached: total 106 solutions
# A terminal state has been reached: total 107 solutions
# A terminal state has been reached: total 108 solutions
# A terminal state has been reached: total 109 solutions
# A terminal state has been reached: total 110 solutions
# A terminal state has been reached: total 111 solutions
# A terminal state has been reached: total 112 solutions
# A terminal state has been reached: total 113 solutions
# A terminal state has been reached: total 114 solutions
# A terminal state has been reached: total 115 solutions
# A terminal state has been reached: total 116 solutions
# A terminal state has been reached: total 117 solutions
# A terminal state has been reached: total 118 solutions
# A terminal state has been reached: total 119 solutions
# A terminal state has been reached: total 120 solutions
# A terminal state has been reached: total 121 solutions
# A terminal state has been reached: total 122 solutions
# A terminal state has been reached: total 123 solutions
# A terminal state has been reached: total 124 solutions
# A terminal state has been reached: total 125 solutions
# A terminal state has been reached: total 126 solutions
# A terminal state has been reached: total 127 solutions
# A terminal state has been reached: total 128 solutions
# A terminal state has been reached: total 129 solutions
# A terminal state has been reached: total 130 solutions
# A terminal state has been reached: total 131 solutions
# A terminal state has been reached: total 132 solutions
# A terminal state has been reached: total 133 solutions
# A terminal state has been reached: total 134 solutions
# A terminal state has been reached: total 135 solutions
# A terminal state has been reached: total 136 solutions
# A terminal state has been reached: total 137 solutions
# A terminal state has been reached: total 138 solutions
# A terminal state has been reached: total 139 solutions
# A terminal state has been reached: total 140 solutions
# A terminal state has been reached: total 141 solutions
# A terminal state has been reached: total 142 solutions
# A terminal state has been reached: total 143 solutions
# A terminal state has been reached: total 144 solutions
# A terminal state has been reached: total 145 solutions
# A terminal state has been reached: total 146 solutions
# A terminal state has been reached: total 147 solutions
# A terminal state has been reached: total 148 solutions
# A terminal state has been reached: total 149 solutions
# A terminal state has been reached: total 150 solutions
# A terminal state has been reached: total 151 solutions
# A terminal state has been reached: total 152 solutions
# A terminal state has been reached: total 153 solutions
# A terminal state has been reached: total 154 solutions
# A terminal state has been reached: total 155 solutions
# A terminal state has been reached: total 156 solutions
# A terminal state has been reached: total 157 solutions
# A terminal state has been reached: total 158 solutions
# A terminal state has been reached: total 159 solutions
# A terminal state has been reached: total 160 solutions
# A terminal state has been reached: total 161 solutions
# A terminal state has been reached: total 162 solutions
# A terminal state has been reached: total 163 solutions
# A terminal state has been reached: total 164 solutions
# A terminal state has been reached: total 165 solutions
# A terminal state has been reached: total 166 solutions
# A terminal state has been reached: total 167 solutions
# A terminal state has been reached: total 168 solutions
# A terminal state has been reached: total 169 solutions
# A terminal state has been reached: total 170 solutions
# A terminal state has been reached: total 171 solutions
# A terminal state has been reached: total 172 solutions
# A terminal state has been reached: total 173 solutions
# A terminal state has been reached: total 174 solutions
# A terminal state has been reached: total 175 solutions
# A terminal state has been reached: total 176 solutions
# A terminal state has been reached: total 177 solutions
# A terminal state has been reached: total 178 solutions
# A terminal state has been reached: total 179 solutions
# A terminal state has been reached: total 180 solutions
# A terminal state has been reached: total 181 solutions
# A terminal state has been reached: total 182 solutions
# A terminal state has been reached: total 183 solutions
# A terminal state has been reached: total 184 solutions
# A terminal state has been reached: total 185 solutions
# A terminal state has been reached: total 186 solutions
# A terminal state has been reached: total 187 solutions
# A terminal state has been reached: total 188 solutions
# A terminal state has been reached: total 189 solutions
# A terminal state has been reached: total 190 solutions
# A terminal state has been reached: total 191 solutions
# A terminal state has been reached: total 192 solutions
# A terminal state has been reached: total 193 solutions
# A terminal state has been reached: total 194 solutions
# A terminal state has been reached: total 195 solutions
# A terminal state has been reached: total 196 solutions
# A terminal state has been reached: total 197 solutions
# A terminal state has been reached: total 198 solutions
# A terminal state has been reached: total 199 solutions
# A terminal state has been reached: total 200 solutions
# A terminal state has been reached: total 201 solutions
# A terminal state has been reached: total 202 solutions
# A terminal state has been reached: total 203 solutions
# A terminal state has been reached: total 204 solutions
# A terminal state has been reached: total 205 solutions
# A terminal state has been reached: total 206 solutions
# A terminal state has been reached: total 207 solutions
# A terminal state has been reached: total 208 solutions
# A terminal state has been reached: total 209 solutions
# A terminal state has been reached: total 210 solutions
# A terminal state has been reached: total 211 solutions
# A terminal state has been reached: total 212 solutions
# A terminal state has been reached: total 213 solutions
# A terminal state has been reached: total 214 solutions
# A terminal state has been reached: total 215 solutions
# A terminal state has been reached: total 216 solutions

# %%
# inspect the result
n_sol =len(breadth_fs_sol_3)
print(f"There are in total {n_sol} number of solution.")
# unzip the solution list
max_util = breadth_fs_sol_3[0][0]
sol_max_score = [node for util, node in breadth_fs_sol_3 if util == max_util]
print(f"The maximum utility of all solution is {max_util}, with {len(sol_max_score)} yielding this utility")
# Out:
# There are in total 216 number of solution.
# The maximum utility of all solution is -90.0, with 216 yielding this utility

# %%
# print the optimal solution
breadth_fs_sol_3[0][1].state
# Out:
#                            time_new  util
# HV 6114 Transavia  2023 12 21 23:40 -15.0
# HV 6902 Transavia  2023 12 21 23:45  -5.0
# KL 1608 KLM        2023 12 21 23:50 -25.0
# HV 5218 Transavia  2023 12 21 23:55   0.0
# HV 5806 Transavia  2023 12 22 00:00 -30.0
# HV 5666 Transavia  2023 12 22 00:05 -15.0

# %% [markdown]
# ### Uniform Cost Search

# %%
AMS21_n5_3_2 = reschedule_problem(df_subset_3, n_runway = 1,max_delay=120, disruption_dur= 15)
AMS21_n5_3_2.solve(best_first_graph_search)
AMS21_n5_3_2_result = AMS21_n5_3_2.display()
# Out:
# The airport resumed service at 23:40
# 0 flights being diverted

# %%
AMS21_n5_3_2_result
# Out:
#                 code            time_sch  pass_load            time_new  util  \
# 0  HV 6114 Transavia 2023-12-21 23:25:00        300 2023-12-21 23:45:00 -20.0
# 1        KL 1608 KLM 2023-12-21 23:25:00        309 2023-12-21 23:40:00 -15.0
# 2  HV 5806 Transavia 2023-12-21 23:30:00        310 2023-12-21 23:50:00 -20.0
# 3  HV 6902 Transavia 2023-12-21 23:40:00        316 2023-12-21 23:55:00 -15.0
# 4  HV 5666 Transavia 2023-12-21 23:50:00        347 2023-12-22 00:00:00 -10.0
# 5  HV 5218 Transavia 2023-12-21 23:55:00        304 2023-12-22 00:05:00 -10.0
#
#    time_dff
# 0      20.0
# 1      15.0
# 2      20.0
# 3      15.0
# 4      10.0
# 5      10.0

# %% [markdown]
# ### Base model (First Come First Served)

# %%
# Instatiate and return the result
AMS21_n5_3 = reschedule_problem(df_subset_3, n_runway = 1,max_delay=120, disruption_dur= 15)
AMS21_n5_3_basemodel = AMS21_n5_3.get_basemodel()
# Out:
# 0 flights being diverted

# %%
AMS21_n5_3_basemodel
# Out:
#                 code            time_sch  pass_load            time_new  util  \
# 0  HV 6114 Transavia 2023-12-21 23:25:00        300 2023-12-21 23:40:00 -15.0
# 1        KL 1608 KLM 2023-12-21 23:25:00        309 2023-12-21 23:45:00 -20.0
# 2  HV 5806 Transavia 2023-12-21 23:30:00        310 2023-12-21 23:50:00 -20.0
# 3  HV 6902 Transavia 2023-12-21 23:40:00        316 2023-12-21 23:55:00 -15.0
# 4  HV 5666 Transavia 2023-12-21 23:50:00        347 2023-12-22 00:00:00 -10.0
# 5  HV 5218 Transavia 2023-12-21 23:55:00        304 2023-12-22 00:05:00 -10.0
#
#    time_dff
# 0      15.0
# 1      20.0
# 2      20.0
# 3      15.0
# 4      10.0
# 5      10.0

# %% [markdown]
# ### Model Evaluation

# %%
# parse the result
compare_df = pd.merge(breadth_fs_sol_3[0][1].state, AMS21_n5_3_2_result[['code',"time_sch",'time_new','util']],
                left_index = True, right_on = 'code', suffixes = ("_breadth","_uniform"))
compare_df = pd.merge(compare_df, AMS21_n5_3_basemodel[['code','time_new','util']],on = 'code')
compare_df.rename(columns={'time_new': 'time_new_base', 'util': 'util_base'}, inplace=True)

# %%
# reorder and print result
compare_df[["code","time_sch",'time_new_breadth', 'util_breadth', 'time_new_uniform',
       'util_uniform','time_new_base','util_base']].sort_values("time_sch")
# Out:
#                 code            time_sch  time_new_breadth  util_breadth  \
# 0  HV 6114 Transavia 2023-12-21 23:25:00  2023 12 21 23:40         -15.0
# 2        KL 1608 KLM 2023-12-21 23:25:00  2023 12 21 23:50         -25.0
# 4  HV 5806 Transavia 2023-12-21 23:30:00  2023 12 22 00:00         -30.0
# 1  HV 6902 Transavia 2023-12-21 23:40:00  2023 12 21 23:45          -5.0
# 5  HV 5666 Transavia 2023-12-21 23:50:00  2023 12 22 00:05         -15.0
# 3  HV 5218 Transavia 2023-12-21 23:55:00  2023 12 21 23:55           0.0
#
#      time_new_uniform  util_uniform       time_new_base  util_base
# 0 2023-12-21 23:45:00         -20.0 2023-12-21 23:40:00      -15.0
# 2 2023-12-21 23:40:00         -15.0 2023-12-21 23:45:00      -20.0
# 4 2023-12-21 23:50:00         -20.0 2023-12-21 23:50:00      -20.0
# 1 2023-12-21 23:55:00         -15.0 2023-12-21 23:55:00      -15.0
# 5 2023-12-22 00:00:00         -10.0 2023-12-22 00:00:00      -10.0
# 3 2023-12-22 00:05:00         -10.0 2023-12-22 00:05:00      -10.0

# %%
# compare the utility
compare_df[['util_breadth','util_uniform','util_base']].sum()
# Out:
# util_breadth   -90.0
# util_uniform   -90.0
# util_base      -90.0
# dtype: float64

# %% [markdown]
# From this simple case, we can see that breadth search is not superior than the uniform cost search for this problem. In fact, this is due to the way we defined the utility function, which is the aggregate time-delayed per flight.
#
# We we were to look at all solutions with the highest utilty returned by breadth-first search, we will see that in this problem set up the order of the flight being assigned actually has no effect on the utility in most cases.
#
# For example, looking a the result directly from above, we see that the solution given by breadth-first search and uniform-cost search seems to be different. However, looking at the result from breadth-first search, we can see that if we were to swap the new time allocated to HV6114 and KL1608, it will still give us a result of the same utility. Therefore, in the following test, we will build up the complexity of the model by considering alternative utility function.

# %% [markdown]
# ## Test 4
# Instead of using the solely the time delayed, let's see if we define utility differently will yield variation in the performance between breadth-first search and uniform-cost search. We will use the `reschedule_custom_u` class to set up the problem. The class object have similar behaviours with the `rescheuld_problem` used above. The only difference is that it takes an additional argument `util_f` which defines the methodology of computing the utility of each rescheduled flight, which is defined as a function of:
# * time-delayed
# * Passenger load

# %% [markdown]
# Recall that the passenger load is a simulated data set that follows a normal distribution:
# $$pass\_load ~ N(\mu= 300,\sigma^2=50^2)$$
#
# The utility of each node is an additive function of all the individual time delayed (in minute) for each rescheduled flight calculated as:
# $$\max(time\_sch - time\_new, max\_delay)$$
#
# Note that utility takes a range of $(max\_delay,0]$, we can rescale with a function of passenger that increases at a decreasing scale. This weigh based on $pass\_load$ should have a range of $[0,1]$ and increases at a decreasing rate. A **proposed scale**:
# $$\arctan(\frac{pass\_load}{200})\frac{2}{\pi}$$
#
# With this function, it is more costly to delay a flight with more passenger than one with less if their originaly scheduled time is the same.

# %%
def util_f(delay, pass_load):
    scaled_pass_load = pass_load / 200
    util = delay * np.arctan(scaled_pass_load) /np.pi * 2
    return util

# %% [markdown]
# ### Bread-First Search

# %%
# subset
df_subset_4 = df.tail(6).reset_index(drop = True)
# instantiate the problem
AMS21_n6_4 = reschedule_custom_u(df_subset_4,util_f, n_runway = 1,max_delay=120, disruption_dur= 15)
# solve the problem
AMS21_n6_4.solve(breadth_first_search)
# the breadth first search returns a list of solution(s)
breadth_fs_sol_4 = AMS21_n6_4.solution

# inspect the result
n_sol =len(breadth_fs_sol_4)
print(f"There are in total {n_sol} number of solution.")
# unzip the solution list
max_util = breadth_fs_sol_4[0][0]
sol_max_score = [node for util, node in breadth_fs_sol_4 if util == max_util]
print(f"The maximum utility of all solution is {max_util}, with {len(sol_max_score)} yielding this utility")
# Out:
# The airport resumed service at 23:40
# Iteration: 1 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 2 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 3 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 4 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 5 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 6 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 7 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 8 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 9 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 10 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 11 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 12 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 13 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 14 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 15 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 16 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 17 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 18 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 19 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 20 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 21 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 22 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 23 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 24 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 25 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 26 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 27 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 28 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 29 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 30 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 31 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 32 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 33 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 34 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 35 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 36 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 37 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 38 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 39 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 40 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 41 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 42 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 43 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 44 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 45 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 46 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 47 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 48 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 49 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 50 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 51 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 52 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 53 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 54 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 55 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 56 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 57 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 58 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 59 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 60 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 61 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 62 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 63 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 64 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 65 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 66 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 67 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 68 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 69 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 70 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 71 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 72 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 73 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 74 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 75 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 76 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 77 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 78 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 79 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 80 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 81 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 82 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 83 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 84 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 85 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 86 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 87 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 88 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 89 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 90 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 91 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 92 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 93 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 94 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 95 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 96 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 97 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 98 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 99 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 100 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 101 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 102 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 103 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 104 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 105 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 106 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 107 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 108 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 109 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 110 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 111 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 112 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 113 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 114 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 115 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 116 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 117 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 118 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 119 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 120 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 121 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 122 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 123 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 124 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 125 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 126 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 127 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 128 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 129 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 130 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 131 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 132 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 133 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 134 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 135 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 136 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 137 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 138 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 139 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 140 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 141 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 142 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 143 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 144 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 145 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 146 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 147 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 148 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 149 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 150 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 151 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 152 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 153 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 154 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 155 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 156 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 157 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 158 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 159 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 160 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 161 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 162 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 163 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 164 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 165 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 166 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 167 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 168 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 169 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 170 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 171 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 172 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 173 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 174 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 175 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 176 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 177 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 178 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 179 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 180 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 181 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 182 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 183 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 184 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 185 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 186 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 187 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 188 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 189 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 190 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 191 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 192 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 193 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 194 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 195 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 196 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 197 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 198 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 199 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 200 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 201 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 202 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 203 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 204 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 205 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 206 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 207 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 208 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 209 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 210 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 211 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 212 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 213 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 214 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 215 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 216 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 217 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 218 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 219 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 220 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 221 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 222 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 223 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 224 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 225 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 226 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 227 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 228 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 229 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 230 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 231 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 232 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 233 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 234 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 235 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 236 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 237 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 238 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 239 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 240 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 241 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 242 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 243 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 244 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 245 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 246 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 247 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 248 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 249 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 250 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 251 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 252 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 253 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 254 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 255 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 256 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 257 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 258 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 259 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 260 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 261 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 262 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 263 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 264 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 265 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 266 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 267 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 268 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 269 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 270 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 271 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 272 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 273 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 274 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 275 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 276 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 277 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 278 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 279 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 280 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 281 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 282 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 283 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 284 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 285 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 286 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 287 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 288 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 289 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 290 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 291 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 292 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 293 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 294 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 295 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 296 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 297 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 298 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 299 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 300 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 301 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 302 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 303 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 304 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 305 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 306 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 307 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 308 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 309 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 310 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 311 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 312 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 313 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 314 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 315 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 316 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 317 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 318 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 319 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 320 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 321 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 322 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 323 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 324 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 325 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 326 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 327 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 328 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 329 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 330 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 331 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 332 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 333 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 334 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 335 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 336 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 337 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 338 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 339 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 340 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 341 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 342 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 343 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 344 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 345 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 346 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 347 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 348 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 349 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 350 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 351 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 352 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 353 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 354 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 355 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 356 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 357 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 358 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 359 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 360 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 361 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 362 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 363 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 364 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 365 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 366 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 367 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 368 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 369 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 370 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 371 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 372 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 373 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 374 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 375 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 376 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 377 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 378 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 379 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 380 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 381 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 382 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 383 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 384 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 385 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 386 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 387 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 388 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 389 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 390 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 391 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 392 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 393 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 394 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 395 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 396 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 397 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 398 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 399 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 400 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 401 at depth 6
# ...
# Iteration: 559 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 560 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 561 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 562 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 563 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 564 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 565 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 566 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 567 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 568 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 569 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 570 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 571 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 572 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 573 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 574 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 575 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 576 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 577 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 578 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 579 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 580 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 581 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 582 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 583 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 584 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 585 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 586 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 587 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 588 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 589 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 590 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 591 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 592 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# A terminal state has been reached: total 1 solutions
# A terminal state has been reached: total 2 solutions
# A terminal state has been reached: total 3 solutions
# A terminal state has been reached: total 4 solutions
# A terminal state has been reached: total 5 solutions
# A terminal state has been reached: total 6 solutions
# A terminal state has been reached: total 7 solutions
# A terminal state has been reached: total 8 solutions
# A terminal state has been reached: total 9 solutions
# A terminal state has been reached: total 10 solutions
# A terminal state has been reached: total 11 solutions
# A terminal state has been reached: total 12 solutions
# A terminal state has been reached: total 13 solutions
# A terminal state has been reached: total 14 solutions
# A terminal state has been reached: total 15 solutions
# A terminal state has been reached: total 16 solutions
# A terminal state has been reached: total 17 solutions
# A terminal state has been reached: total 18 solutions
# A terminal state has been reached: total 19 solutions
# A terminal state has been reached: total 20 solutions
# A terminal state has been reached: total 21 solutions
# A terminal state has been reached: total 22 solutions
# A terminal state has been reached: total 23 solutions
# A terminal state has been reached: total 24 solutions
# A terminal state has been reached: total 25 solutions
# A terminal state has been reached: total 26 solutions
# A terminal state has been reached: total 27 solutions
# A terminal state has been reached: total 28 solutions
# A terminal state has been reached: total 29 solutions
# A terminal state has been reached: total 30 solutions
# A terminal state has been reached: total 31 solutions
# A terminal state has been reached: total 32 solutions
# A terminal state has been reached: total 33 solutions
# A terminal state has been reached: total 34 solutions
# A terminal state has been reached: total 35 solutions
# A terminal state has been reached: total 36 solutions
# A terminal state has been reached: total 37 solutions
# A terminal state has been reached: total 38 solutions
# A terminal state has been reached: total 39 solutions
# A terminal state has been reached: total 40 solutions
# A terminal state has been reached: total 41 solutions
# A terminal state has been reached: total 42 solutions
# A terminal state has been reached: total 43 solutions
# A terminal state has been reached: total 44 solutions
# A terminal state has been reached: total 45 solutions
# A terminal state has been reached: total 46 solutions
# A terminal state has been reached: total 47 solutions
# A terminal state has been reached: total 48 solutions
# A terminal state has been reached: total 49 solutions
# A terminal state has been reached: total 50 solutions
# A terminal state has been reached: total 51 solutions
# A terminal state has been reached: total 52 solutions
# A terminal state has been reached: total 53 solutions
# A terminal state has been reached: total 54 solutions
# A terminal state has been reached: total 55 solutions
# A terminal state has been reached: total 56 solutions
# A terminal state has been reached: total 57 solutions
# A terminal state has been reached: total 58 solutions
# A terminal state has been reached: total 59 solutions
# A terminal state has been reached: total 60 solutions
# A terminal state has been reached: total 61 solutions
# A terminal state has been reached: total 62 solutions
# A terminal state has been reached: total 63 solutions
# A terminal state has been reached: total 64 solutions
# A terminal state has been reached: total 65 solutions
# A terminal state has been reached: total 66 solutions
# A terminal state has been reached: total 67 solutions
# A terminal state has been reached: total 68 solutions
# A terminal state has been reached: total 69 solutions
# A terminal state has been reached: total 70 solutions
# A terminal state has been reached: total 71 solutions
# A terminal state has been reached: total 72 solutions
# A terminal state has been reached: total 73 solutions
# A terminal state has been reached: total 74 solutions
# A terminal state has been reached: total 75 solutions
# A terminal state has been reached: total 76 solutions
# A terminal state has been reached: total 77 solutions
# A terminal state has been reached: total 78 solutions
# A terminal state has been reached: total 79 solutions
# A terminal state has been reached: total 80 solutions
# A terminal state has been reached: total 81 solutions
# A terminal state has been reached: total 82 solutions
# A terminal state has been reached: total 83 solutions
# A terminal state has been reached: total 84 solutions
# A terminal state has been reached: total 85 solutions
# A terminal state has been reached: total 86 solutions
# A terminal state has been reached: total 87 solutions
# A terminal state has been reached: total 88 solutions
# A terminal state has been reached: total 89 solutions
# A terminal state has been reached: total 90 solutions
# A terminal state has been reached: total 91 solutions
# A terminal state has been reached: total 92 solutions
# A terminal state has been reached: total 93 solutions
# A terminal state has been reached: total 94 solutions
# A terminal state has been reached: total 95 solutions
# A terminal state has been reached: total 96 solutions
# A terminal state has been reached: total 97 solutions
# A terminal state has been reached: total 98 solutions
# A terminal state has been reached: total 99 solutions
# A terminal state has been reached: total 100 solutions
# A terminal state has been reached: total 101 solutions
# A terminal state has been reached: total 102 solutions
# A terminal state has been reached: total 103 solutions
# A terminal state has been reached: total 104 solutions
# A terminal state has been reached: total 105 solutions
# A terminal state has been reached: total 106 solutions
# A terminal state has been reached: total 107 solutions
# A terminal state has been reached: total 108 solutions
# A terminal state has been reached: total 109 solutions
# A terminal state has been reached: total 110 solutions
# A terminal state has been reached: total 111 solutions
# A terminal state has been reached: total 112 solutions
# A terminal state has been reached: total 113 solutions
# A terminal state has been reached: total 114 solutions
# A terminal state has been reached: total 115 solutions
# A terminal state has been reached: total 116 solutions
# A terminal state has been reached: total 117 solutions
# A terminal state has been reached: total 118 solutions
# A terminal state has been reached: total 119 solutions
# A terminal state has been reached: total 120 solutions
# A terminal state has been reached: total 121 solutions
# A terminal state has been reached: total 122 solutions
# A terminal state has been reached: total 123 solutions
# A terminal state has been reached: total 124 solutions
# A terminal state has been reached: total 125 solutions
# A terminal state has been reached: total 126 solutions
# A terminal state has been reached: total 127 solutions
# A terminal state has been reached: total 128 solutions
# A terminal state has been reached: total 129 solutions
# A terminal state has been reached: total 130 solutions
# A terminal state has been reached: total 131 solutions
# A terminal state has been reached: total 132 solutions
# A terminal state has been reached: total 133 solutions
# A terminal state has been reached: total 134 solutions
# A terminal state has been reached: total 135 solutions
# A terminal state has been reached: total 136 solutions
# A terminal state has been reached: total 137 solutions
# A terminal state has been reached: total 138 solutions
# A terminal state has been reached: total 139 solutions
# A terminal state has been reached: total 140 solutions
# A terminal state has been reached: total 141 solutions
# A terminal state has been reached: total 142 solutions
# A terminal state has been reached: total 143 solutions
# A terminal state has been reached: total 144 solutions
# A terminal state has been reached: total 145 solutions
# A terminal state has been reached: total 146 solutions
# A terminal state has been reached: total 147 solutions
# A terminal state has been reached: total 148 solutions
# A terminal state has been reached: total 149 solutions
# A terminal state has been reached: total 150 solutions
# A terminal state has been reached: total 151 solutions
# A terminal state has been reached: total 152 solutions
# A terminal state has been reached: total 153 solutions
# A terminal state has been reached: total 154 solutions
# A terminal state has been reached: total 155 solutions
# A terminal state has been reached: total 156 solutions
# A terminal state has been reached: total 157 solutions
# A terminal state has been reached: total 158 solutions
# A terminal state has been reached: total 159 solutions
# A terminal state has been reached: total 160 solutions
# A terminal state has been reached: total 161 solutions
# A terminal state has been reached: total 162 solutions
# A terminal state has been reached: total 163 solutions
# A terminal state has been reached: total 164 solutions
# A terminal state has been reached: total 165 solutions
# A terminal state has been reached: total 166 solutions
# A terminal state has been reached: total 167 solutions
# A terminal state has been reached: total 168 solutions
# A terminal state has been reached: total 169 solutions
# A terminal state has been reached: total 170 solutions
# A terminal state has been reached: total 171 solutions
# A terminal state has been reached: total 172 solutions
# A terminal state has been reached: total 173 solutions
# A terminal state has been reached: total 174 solutions
# A terminal state has been reached: total 175 solutions
# A terminal state has been reached: total 176 solutions
# A terminal state has been reached: total 177 solutions
# A terminal state has been reached: total 178 solutions
# A terminal state has been reached: total 179 solutions
# A terminal state has been reached: total 180 solutions
# A terminal state has been reached: total 181 solutions
# A terminal state has been reached: total 182 solutions
# A terminal state has been reached: total 183 solutions
# A terminal state has been reached: total 184 solutions
# A terminal state has been reached: total 185 solutions
# A terminal state has been reached: total 186 solutions
# A terminal state has been reached: total 187 solutions
# A terminal state has been reached: total 188 solutions
# A terminal state has been reached: total 189 solutions
# A terminal state has been reached: total 190 solutions
# A terminal state has been reached: total 191 solutions
# A terminal state has been reached: total 192 solutions
# A terminal state has been reached: total 193 solutions
# A terminal state has been reached: total 194 solutions
# A terminal state has been reached: total 195 solutions
# A terminal state has been reached: total 196 solutions
# A terminal state has been reached: total 197 solutions
# A terminal state has been reached: total 198 solutions
# A terminal state has been reached: total 199 solutions
# A terminal state has been reached: total 200 solutions
# A terminal state has been reached: total 201 solutions
# A terminal state has been reached: total 202 solutions
# A terminal state has been reached: total 203 solutions
# A terminal state has been reached: total 204 solutions
# A terminal state has been reached: total 205 solutions
# A terminal state has been reached: total 206 solutions
# A terminal state has been reached: total 207 solutions
# A terminal state has been reached: total 208 solutions
# A terminal state has been reached: total 209 solutions
# A terminal state has been reached: total 210 solutions
# A terminal state has been reached: total 211 solutions
# A terminal state has been reached: total 212 solutions
# A terminal state has been reached: total 213 solutions
# A terminal state has been reached: total 214 solutions
# A terminal state has been reached: total 215 solutions
# A terminal state has been reached: total 216 solutions
# There are in total 216 number of solution.
# The maximum utility of all solution is -56.73197465866323, with 1 yielding this utility

# %%
# print the optimal solution
breadth_fs_sol_4[0][1].state
# Out:
#                            time_new       util
# HV 6902 Transavia  2023 12 21 23:40   0.000000
# HV 5806 Transavia  2023 12 21 23:45  -9.528576
# HV 5666 Transavia  2023 12 21 23:50   0.000000
# KL 1608 KLM        2023 12 21 23:55 -19.029023
# HV 5218 Transavia  2023 12 22 00:00  -3.147738
# HV 6114 Transavia  2023 12 22 00:05 -25.026637

# %% [markdown]
# ### Uniform Cost Search

# %%
# Instatiate and return the result
AMS21_n6_4_2 = reschedule_custom_u(df_subset_4,util_f, n_runway = 1,max_delay=120, disruption_dur= 15)
AMS21_n6_4_2.solve(best_first_graph_search)
AMS21_n6_4_2_result = AMS21_n6_4_2.display()
# Out:
# The airport resumed service at 23:40
# 0 flights being diverted

# %% [markdown]
# ### Base model (First Come First Served)

# %%
AMS21_n6_4_basemodel = AMS21_n6_4.get_basemodel()
# Out:
# 0 flights being diverted

# %% [markdown]
# ### Model Evaluation

# %%
# parse the result
compare_df = pd.merge(breadth_fs_sol_4[0][1].state, AMS21_n6_4_2_result[['code',"time_sch",'time_new','util']],
                left_index = True, right_on = 'code', suffixes = ("_breadth","_uniform"))
compare_df = pd.merge(compare_df, AMS21_n6_4_basemodel[['code','time_new','util']],on = 'code')
compare_df.rename(columns={'time_new': 'time_new_base', 'util': 'util_base'}, inplace=True)
# reorder and print result
compare_df[["code","time_sch",'time_new_breadth', 'util_breadth', 'time_new_uniform',
       'util_uniform','time_new_base','util_base']].sort_values("time_sch")
# Out:
#                 code            time_sch  time_new_breadth  util_breadth  \
# 3        KL 1608 KLM 2023-12-21 23:25:00  2023 12 21 23:55    -19.029023
# 5  HV 6114 Transavia 2023-12-21 23:25:00  2023 12 22 00:05    -25.026637
# 1  HV 5806 Transavia 2023-12-21 23:30:00  2023 12 21 23:45     -9.528576
# 0  HV 6902 Transavia 2023-12-21 23:40:00  2023 12 21 23:40      0.000000
# 2  HV 5666 Transavia 2023-12-21 23:50:00  2023 12 21 23:50      0.000000
# 4  HV 5218 Transavia 2023-12-21 23:55:00  2023 12 22 00:00     -3.147738
#
#      time_new_uniform  util_uniform       time_new_base  util_base
# 3 2023-12-21 23:40:00     -9.514512 2023-12-21 23:45:00 -12.686015
# 5 2023-12-21 23:45:00    -12.513318 2023-12-21 23:40:00  -9.384989
# 1 2023-12-21 23:50:00    -12.704768 2023-12-21 23:50:00 -12.704768
# 0 2023-12-21 23:55:00     -9.611636 2023-12-21 23:55:00  -9.611636
# 2 2023-12-22 00:00:00     -6.671354 2023-12-22 00:00:00  -6.671354
# 4 2023-12-22 00:05:00     -6.295477 2023-12-22 00:05:00  -6.295477

# %%
# compare the utility
compare_df[['util_breadth','util_uniform','util_base']].sum()
# Out:
# util_breadth   -56.731975
# util_uniform   -57.311066
# util_base      -57.354240
# dtype: float64

# %% [markdown]
# From this result, we do see that the uniform-cost search does not yield the optimal solution.

# %% [markdown]
# ## Test 5
# Altervatively, utility function with the passenger weigh defined as follow:
# $$\frac{e^{pass\_load} -1}{e^{pass\_load}}$$
#
# This function stills follows the desired property, having a range of $[0,1]$ and increases with a decreasing rate.

# %%
def util_f(delay, pass_load):
    scaled_pass_load = pass_load/200
    util = delay * (np.exp(scaled_pass_load) - 1) / np.exp(scaled_pass_load)
    return util

# %% [markdown]
# ### Breadth First Search

# %%
# subset
df_subset_5 = df.tail(6).reset_index(drop = True)
# instantiate the problem
AMS21_n6_5 = reschedule_custom_u(df_subset_5, util_f, n_runway = 1,max_delay=120, disruption_dur= 15)
# solve the problem
AMS21_n6_5.solve(breadth_first_search)
# the breadth first search returns a list of solution(s)
breadth_fs_sol_5 = AMS21_n6_5.solution

# inspect the result
n_sol =len(breadth_fs_sol_5)
print(f"There are in total {n_sol} number of solution.")
# unzip the solution list
max_util = breadth_fs_sol_5[0][0]
sol_max_score = [node for util, node in breadth_fs_sol_5 if util == max_util]
print(f"The maximum utility of all solution is {max_util}, with {len(sol_max_score)} yielding this utility")
# Out:
# The airport resumed service at 23:40
# Iteration: 1 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 2 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 3 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 4 at depth 1
# Check if the depth is consistent withe the node state.
# There should be 1.0 timeslot iterated.
# Iteration: 5 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 6 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 7 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 8 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 9 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 10 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 11 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 12 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 13 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 14 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 15 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 16 at depth 2
# Check if the depth is consistent withe the node state.
# There should be 2.0 timeslot iterated.
# Iteration: 17 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 18 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 19 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 20 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 21 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 22 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 23 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 24 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 25 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 26 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 27 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 28 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 29 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 30 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 31 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 32 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 33 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 34 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 35 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 36 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 37 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 38 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 39 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 40 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 41 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 42 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 43 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 44 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 45 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 46 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 47 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 48 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 49 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 50 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 51 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 52 at depth 3
# Check if the depth is consistent withe the node state.
# There should be 3.0 timeslot iterated.
# Iteration: 53 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 54 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 55 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 56 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 57 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 58 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 59 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 60 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 61 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 62 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 63 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 64 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 65 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 66 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 67 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 68 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 69 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 70 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 71 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 72 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 73 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 74 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 75 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 76 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 77 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 78 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 79 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 80 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 81 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 82 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 83 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 84 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 85 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 86 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 87 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 88 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 89 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 90 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 91 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 92 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 93 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 94 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 95 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 96 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 97 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 98 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 99 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 100 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 101 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 102 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 103 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 104 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 105 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 106 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 107 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 108 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 109 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 110 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 111 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 112 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 113 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 114 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 115 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 116 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 117 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 118 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 119 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 120 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 121 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 122 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 123 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 124 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 125 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 126 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 127 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 128 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 129 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 130 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 131 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 132 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 133 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 134 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 135 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 136 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 137 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 138 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 139 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 140 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 141 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 142 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 143 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 144 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 145 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 146 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 147 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 148 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 149 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 150 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 151 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 152 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 153 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 154 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 155 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 156 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 157 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 158 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 159 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 160 at depth 4
# Check if the depth is consistent withe the node state.
# There should be 4.0 timeslot iterated.
# Iteration: 161 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 162 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 163 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 164 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 165 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 166 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 167 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 168 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 169 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 170 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 171 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 172 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 173 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 174 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 175 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 176 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 177 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 178 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 179 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 180 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 181 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 182 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 183 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 184 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 185 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 186 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 187 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 188 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 189 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 190 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 191 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 192 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 193 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 194 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 195 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 196 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 197 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 198 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 199 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 200 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 201 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 202 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 203 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 204 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 205 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 206 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 207 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 208 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 209 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 210 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 211 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 212 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 213 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 214 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 215 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 216 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 217 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 218 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 219 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 220 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 221 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 222 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 223 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 224 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 225 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 226 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 227 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 228 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 229 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 230 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 231 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 232 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 233 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 234 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 235 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 236 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 237 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 238 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 239 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 240 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 241 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 242 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 243 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 244 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 245 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 246 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 247 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 248 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 249 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 250 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 251 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 252 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 253 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 254 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 255 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 256 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 257 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 258 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 259 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 260 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 261 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 262 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 263 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 264 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 265 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 266 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 267 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 268 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 269 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 270 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 271 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 272 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 273 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 274 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 275 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 276 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 277 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 278 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 279 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 280 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 281 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 282 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 283 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 284 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 285 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 286 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 287 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 288 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 289 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 290 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 291 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 292 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 293 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 294 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 295 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 296 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 297 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 298 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 299 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 300 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 301 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 302 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 303 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 304 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 305 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 306 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 307 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 308 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 309 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 310 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 311 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 312 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 313 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 314 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 315 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 316 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 317 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 318 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 319 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 320 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 321 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 322 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 323 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 324 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 325 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 326 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 327 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 328 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 329 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 330 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 331 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 332 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 333 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 334 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 335 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 336 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 337 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 338 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 339 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 340 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 341 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 342 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 343 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 344 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 345 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 346 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 347 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 348 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 349 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 350 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 351 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 352 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 353 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 354 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 355 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 356 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 357 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 358 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 359 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 360 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 361 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 362 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 363 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 364 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 365 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 366 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 367 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 368 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 369 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 370 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 371 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 372 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 373 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 374 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 375 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 376 at depth 5
# Check if the depth is consistent withe the node state.
# There should be 5.0 timeslot iterated.
# Iteration: 377 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 378 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 379 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 380 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 381 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 382 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 383 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 384 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 385 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 386 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 387 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 388 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 389 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 390 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 391 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 392 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 393 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 394 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 395 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 396 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 397 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 398 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 399 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 400 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 401 at depth 6
# ...
# Iteration: 559 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 560 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 561 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 562 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 563 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 564 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 565 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 566 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 567 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 568 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 569 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 570 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 571 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 572 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 573 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 574 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 575 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 576 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 577 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 578 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 579 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 580 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 581 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 582 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 583 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 584 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 585 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 586 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 587 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 588 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 589 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 590 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 591 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# Iteration: 592 at depth 6
# Check if the depth is consistent withe the node state.
# There should be 6.0 timeslot iterated.
# A terminal state has been reached: total 1 solutions
# A terminal state has been reached: total 2 solutions
# A terminal state has been reached: total 3 solutions
# A terminal state has been reached: total 4 solutions
# A terminal state has been reached: total 5 solutions
# A terminal state has been reached: total 6 solutions
# A terminal state has been reached: total 7 solutions
# A terminal state has been reached: total 8 solutions
# A terminal state has been reached: total 9 solutions
# A terminal state has been reached: total 10 solutions
# A terminal state has been reached: total 11 solutions
# A terminal state has been reached: total 12 solutions
# A terminal state has been reached: total 13 solutions
# A terminal state has been reached: total 14 solutions
# A terminal state has been reached: total 15 solutions
# A terminal state has been reached: total 16 solutions
# A terminal state has been reached: total 17 solutions
# A terminal state has been reached: total 18 solutions
# A terminal state has been reached: total 19 solutions
# A terminal state has been reached: total 20 solutions
# A terminal state has been reached: total 21 solutions
# A terminal state has been reached: total 22 solutions
# A terminal state has been reached: total 23 solutions
# A terminal state has been reached: total 24 solutions
# A terminal state has been reached: total 25 solutions
# A terminal state has been reached: total 26 solutions
# A terminal state has been reached: total 27 solutions
# A terminal state has been reached: total 28 solutions
# A terminal state has been reached: total 29 solutions
# A terminal state has been reached: total 30 solutions
# A terminal state has been reached: total 31 solutions
# A terminal state has been reached: total 32 solutions
# A terminal state has been reached: total 33 solutions
# A terminal state has been reached: total 34 solutions
# A terminal state has been reached: total 35 solutions
# A terminal state has been reached: total 36 solutions
# A terminal state has been reached: total 37 solutions
# A terminal state has been reached: total 38 solutions
# A terminal state has been reached: total 39 solutions
# A terminal state has been reached: total 40 solutions
# A terminal state has been reached: total 41 solutions
# A terminal state has been reached: total 42 solutions
# A terminal state has been reached: total 43 solutions
# A terminal state has been reached: total 44 solutions
# A terminal state has been reached: total 45 solutions
# A terminal state has been reached: total 46 solutions
# A terminal state has been reached: total 47 solutions
# A terminal state has been reached: total 48 solutions
# A terminal state has been reached: total 49 solutions
# A terminal state has been reached: total 50 solutions
# A terminal state has been reached: total 51 solutions
# A terminal state has been reached: total 52 solutions
# A terminal state has been reached: total 53 solutions
# A terminal state has been reached: total 54 solutions
# A terminal state has been reached: total 55 solutions
# A terminal state has been reached: total 56 solutions
# A terminal state has been reached: total 57 solutions
# A terminal state has been reached: total 58 solutions
# A terminal state has been reached: total 59 solutions
# A terminal state has been reached: total 60 solutions
# A terminal state has been reached: total 61 solutions
# A terminal state has been reached: total 62 solutions
# A terminal state has been reached: total 63 solutions
# A terminal state has been reached: total 64 solutions
# A terminal state has been reached: total 65 solutions
# A terminal state has been reached: total 66 solutions
# A terminal state has been reached: total 67 solutions
# A terminal state has been reached: total 68 solutions
# A terminal state has been reached: total 69 solutions
# A terminal state has been reached: total 70 solutions
# A terminal state has been reached: total 71 solutions
# A terminal state has been reached: total 72 solutions
# A terminal state has been reached: total 73 solutions
# A terminal state has been reached: total 74 solutions
# A terminal state has been reached: total 75 solutions
# A terminal state has been reached: total 76 solutions
# A terminal state has been reached: total 77 solutions
# A terminal state has been reached: total 78 solutions
# A terminal state has been reached: total 79 solutions
# A terminal state has been reached: total 80 solutions
# A terminal state has been reached: total 81 solutions
# A terminal state has been reached: total 82 solutions
# A terminal state has been reached: total 83 solutions
# A terminal state has been reached: total 84 solutions
# A terminal state has been reached: total 85 solutions
# A terminal state has been reached: total 86 solutions
# A terminal state has been reached: total 87 solutions
# A terminal state has been reached: total 88 solutions
# A terminal state has been reached: total 89 solutions
# A terminal state has been reached: total 90 solutions
# A terminal state has been reached: total 91 solutions
# A terminal state has been reached: total 92 solutions
# A terminal state has been reached: total 93 solutions
# A terminal state has been reached: total 94 solutions
# A terminal state has been reached: total 95 solutions
# A terminal state has been reached: total 96 solutions
# A terminal state has been reached: total 97 solutions
# A terminal state has been reached: total 98 solutions
# A terminal state has been reached: total 99 solutions
# A terminal state has been reached: total 100 solutions
# A terminal state has been reached: total 101 solutions
# A terminal state has been reached: total 102 solutions
# A terminal state has been reached: total 103 solutions
# A terminal state has been reached: total 104 solutions
# A terminal state has been reached: total 105 solutions
# A terminal state has been reached: total 106 solutions
# A terminal state has been reached: total 107 solutions
# A terminal state has been reached: total 108 solutions
# A terminal state has been reached: total 109 solutions
# A terminal state has been reached: total 110 solutions
# A terminal state has been reached: total 111 solutions
# A terminal state has been reached: total 112 solutions
# A terminal state has been reached: total 113 solutions
# A terminal state has been reached: total 114 solutions
# A terminal state has been reached: total 115 solutions
# A terminal state has been reached: total 116 solutions
# A terminal state has been reached: total 117 solutions
# A terminal state has been reached: total 118 solutions
# A terminal state has been reached: total 119 solutions
# A terminal state has been reached: total 120 solutions
# A terminal state has been reached: total 121 solutions
# A terminal state has been reached: total 122 solutions
# A terminal state has been reached: total 123 solutions
# A terminal state has been reached: total 124 solutions
# A terminal state has been reached: total 125 solutions
# A terminal state has been reached: total 126 solutions
# A terminal state has been reached: total 127 solutions
# A terminal state has been reached: total 128 solutions
# A terminal state has been reached: total 129 solutions
# A terminal state has been reached: total 130 solutions
# A terminal state has been reached: total 131 solutions
# A terminal state has been reached: total 132 solutions
# A terminal state has been reached: total 133 solutions
# A terminal state has been reached: total 134 solutions
# A terminal state has been reached: total 135 solutions
# A terminal state has been reached: total 136 solutions
# A terminal state has been reached: total 137 solutions
# A terminal state has been reached: total 138 solutions
# A terminal state has been reached: total 139 solutions
# A terminal state has been reached: total 140 solutions
# A terminal state has been reached: total 141 solutions
# A terminal state has been reached: total 142 solutions
# A terminal state has been reached: total 143 solutions
# A terminal state has been reached: total 144 solutions
# A terminal state has been reached: total 145 solutions
# A terminal state has been reached: total 146 solutions
# A terminal state has been reached: total 147 solutions
# A terminal state has been reached: total 148 solutions
# A terminal state has been reached: total 149 solutions
# A terminal state has been reached: total 150 solutions
# A terminal state has been reached: total 151 solutions
# A terminal state has been reached: total 152 solutions
# A terminal state has been reached: total 153 solutions
# A terminal state has been reached: total 154 solutions
# A terminal state has been reached: total 155 solutions
# A terminal state has been reached: total 156 solutions
# A terminal state has been reached: total 157 solutions
# A terminal state has been reached: total 158 solutions
# A terminal state has been reached: total 159 solutions
# A terminal state has been reached: total 160 solutions
# A terminal state has been reached: total 161 solutions
# A terminal state has been reached: total 162 solutions
# A terminal state has been reached: total 163 solutions
# A terminal state has been reached: total 164 solutions
# A terminal state has been reached: total 165 solutions
# A terminal state has been reached: total 166 solutions
# A terminal state has been reached: total 167 solutions
# A terminal state has been reached: total 168 solutions
# A terminal state has been reached: total 169 solutions
# A terminal state has been reached: total 170 solutions
# A terminal state has been reached: total 171 solutions
# A terminal state has been reached: total 172 solutions
# A terminal state has been reached: total 173 solutions
# A terminal state has been reached: total 174 solutions
# A terminal state has been reached: total 175 solutions
# A terminal state has been reached: total 176 solutions
# A terminal state has been reached: total 177 solutions
# A terminal state has been reached: total 178 solutions
# A terminal state has been reached: total 179 solutions
# A terminal state has been reached: total 180 solutions
# A terminal state has been reached: total 181 solutions
# A terminal state has been reached: total 182 solutions
# A terminal state has been reached: total 183 solutions
# A terminal state has been reached: total 184 solutions
# A terminal state has been reached: total 185 solutions
# A terminal state has been reached: total 186 solutions
# A terminal state has been reached: total 187 solutions
# A terminal state has been reached: total 188 solutions
# A terminal state has been reached: total 189 solutions
# A terminal state has been reached: total 190 solutions
# A terminal state has been reached: total 191 solutions
# A terminal state has been reached: total 192 solutions
# A terminal state has been reached: total 193 solutions
# A terminal state has been reached: total 194 solutions
# A terminal state has been reached: total 195 solutions
# A terminal state has been reached: total 196 solutions
# A terminal state has been reached: total 197 solutions
# A terminal state has been reached: total 198 solutions
# A terminal state has been reached: total 199 solutions
# A terminal state has been reached: total 200 solutions
# A terminal state has been reached: total 201 solutions
# A terminal state has been reached: total 202 solutions
# A terminal state has been reached: total 203 solutions
# A terminal state has been reached: total 204 solutions
# A terminal state has been reached: total 205 solutions
# A terminal state has been reached: total 206 solutions
# A terminal state has been reached: total 207 solutions
# A terminal state has been reached: total 208 solutions
# A terminal state has been reached: total 209 solutions
# A terminal state has been reached: total 210 solutions
# A terminal state has been reached: total 211 solutions
# A terminal state has been reached: total 212 solutions
# A terminal state has been reached: total 213 solutions
# A terminal state has been reached: total 214 solutions
# A terminal state has been reached: total 215 solutions
# A terminal state has been reached: total 216 solutions
# There are in total 216 number of solution.
# The maximum utility of all solution is -70.39815841521312, with 1 yielding this utility

# %% [markdown]
# ### Uniform Cost Search

# %%
# Instatiate and return the result
AMS21_n6_5_2 = reschedule_custom_u(df_subset_5, util_f, n_runway = 1,max_delay=120, disruption_dur= 15)
AMS21_n6_5_2.solve(best_first_graph_search)
AMS21_n6_5_2_result = AMS21_n6_5_2.display()
# Out:
# The airport resumed service at 23:40
# 0 flights being diverted

# %% [markdown]
# ### Base model (First Come First Served)

# %%
AMS21_n6_5_basemodel = AMS21_n6_5.get_basemodel()
# Out:
# 0 flights being diverted

# %% [markdown]
# ### Model Evaluation

# %%
# parse the result
compare_df = pd.merge(breadth_fs_sol_5[0][1].state, AMS21_n6_5_2_result[['code',"time_sch",'time_new','util']],
                left_index = True, right_on = 'code', suffixes = ("_breadth","_uniform"))
compare_df = pd.merge(compare_df, AMS21_n6_5_basemodel[['code','time_new','util']],on = 'code')
compare_df.rename(columns={'time_new': 'time_new_base', 'util': 'util_base'}, inplace=True)
# reorder and print result
compare_df[["code","time_sch",'time_new_breadth', 'util_breadth', 'time_new_uniform',
       'util_uniform','time_new_base','util_base']].sort_values("time_sch")
# Out:
#                 code            time_sch  time_new_breadth  util_breadth  \
# 3        KL 1608 KLM 2023-12-21 23:25:00  2023 12 21 23:55    -23.600644
# 5  HV 6114 Transavia 2023-12-21 23:25:00  2023 12 22 00:05    -31.074794
# 1  HV 5806 Transavia 2023-12-21 23:30:00  2023 12 21 23:45    -11.816280
# 0  HV 6902 Transavia 2023-12-21 23:40:00  2023 12 21 23:40      0.000000
# 2  HV 5666 Transavia 2023-12-21 23:50:00  2023 12 21 23:50      0.000000
# 4  HV 5218 Transavia 2023-12-21 23:55:00  2023 12 22 00:00     -3.906441
#
#      time_new_uniform  util_uniform       time_new_base  util_base
# 3 2023-12-21 23:40:00    -11.800322 2023-12-21 23:45:00 -15.733763
# 5 2023-12-21 23:45:00    -15.537397 2023-12-21 23:40:00 -11.653048
# 1 2023-12-21 23:50:00    -15.755041 2023-12-21 23:50:00 -15.755041
# 0 2023-12-21 23:55:00    -11.910374 2023-12-21 23:55:00 -11.910374
# 2 2023-12-22 00:00:00     -8.235998 2023-12-22 00:00:00  -8.235998
# 4 2023-12-22 00:05:00     -7.812881 2023-12-22 00:05:00  -7.812881

# %%
# compare the utility
compare_df[['util_breadth','util_uniform','util_base']].sum()
# Out:
# util_breadth   -70.398158
# util_uniform   -71.052012
# util_base      -71.101103
# dtype: float64

# %% [markdown]
# ## Test 6
# Another assumption we can make is that the further away it is from the current time, it is more uncertain to realised. Therefore, the uility of future should have a lower weight compare to the utility of the current weight. We will have to overwrite the `compute_util`.
#
#
# The discount rate should take the value between 1 - 2. We will use the same utility function as defined from test 6.

# %%
def util_f(delay, pass_load):
    scaled_pass_load = pass_load/200
    util = delay * (np.exp(scaled_pass_load) - 1) / np.exp(scaled_pass_load)
    return util

# %%
# subset
df_subset_6 = df.tail(20).reset_index(drop = True)
# Instatiate and return the result
AMS21_n20_6 = reschedule_custom_u_dis(df_subset_6, util_f, dis_rate= 1.3, n_runway = 1,max_delay=120, disruption_dur= 30)
AMS21_n20_6.solve(best_first_graph_search)
AMS21_n20_6_result = AMS21_n20_6.display()
# display the result
AMS21_n20_6_result
# Out:
# The airport resumed service at 23:00
# 0 flights being diverted
#                   code            time_sch  pass_load            time_new  \
# 0      OR 3802 TUI fly 2023-12-21 22:30:00        236 2023-12-21 23:00:00
# 1    LH 2310 Lufthansa 2023-12-21 22:35:00        339 2023-12-21 23:10:00
# 2          KL 1032 KLM 2023-12-21 22:35:00        344 2023-12-21 23:05:00
# 3   AZ 118 ITA Airways 2023-12-21 22:40:00        346 2023-12-21 23:15:00
# 4          KL 1706 KLM 2023-12-21 23:00:00        316 2023-12-21 23:25:00
# 5           KL 980 KLM 2023-12-21 23:00:00        186 2023-12-21 23:35:00
# 6          KL 1118 KLM 2023-12-21 23:00:00        263 2023-12-21 23:30:00
# 7          KL 1434 KLM 2023-12-21 23:00:00        343 2023-12-21 23:20:00
# 8          KL 1136 KLM 2023-12-21 23:05:00        263 2023-12-21 23:40:00
# 9    HV 5136 Transavia 2023-12-21 23:15:00        339 2023-12-21 23:50:00
# 10   HV 6886 Transavia 2023-12-21 23:15:00        386 2023-12-21 23:45:00
# 11         KL 1082 KLM 2023-12-21 23:20:00        375 2023-12-21 23:55:00
# 12   HV 5358 Transavia 2023-12-21 23:20:00        239 2023-12-22 00:05:00
# 13         KL 1834 KLM 2023-12-21 23:20:00        319 2023-12-22 00:00:00
# 14   HV 6114 Transavia 2023-12-21 23:25:00        300 2023-12-22 00:15:00
# 15         KL 1608 KLM 2023-12-21 23:25:00        309 2023-12-22 00:10:00
# 16   HV 5806 Transavia 2023-12-21 23:30:00        310 2023-12-22 00:20:00
# 17   HV 6902 Transavia 2023-12-21 23:40:00        316 2023-12-22 00:25:00
# 18   HV 5666 Transavia 2023-12-21 23:50:00        347 2023-12-22 00:30:00
# 19   HV 5218 Transavia 2023-12-21 23:55:00        304 2023-12-22 00:35:00
#
#           util  time_dff
# 0  -100.308997      30.0
# 1  -106.093362      35.0
# 2   -91.442098      30.0
# 3   -82.241530      35.0
# 4   -19.850623      25.0
# 5   -21.190620      35.0
# 6   -21.945770      30.0
# 7   -16.400726      20.0
# 8   -19.694922      35.0
# 9   -13.005929      35.0
# 10  -11.672988      30.0
# 11  -10.375189      35.0
# 12  -10.986423      45.0
# 13  -11.163355      40.0
# 14  -10.461682      50.0
# 15   -9.534509      45.0
# 16   -8.160174      50.0
# 17   -4.380259      45.0
# 18   -2.389696      40.0
# 19   -1.743791      40.0

# %%
# subset
df_subset_6 = df.tail(20).reset_index(drop = True)
# Instatiate and return the result
AMS21_n20_6 = reschedule_custom_u(df_subset_6, util_f, n_runway = 1,
                                  max_delay=120, disruption_dur= 30)
AMS21_n20_6.solve(best_first_graph_search)
AMS21_n20_6_result = AMS21_n20_6.display()
# display the result
AMS21_n20_6_result
# Out:
# The airport resumed service at 23:00
# 0 flights being diverted
#                   code            time_sch  pass_load            time_new  \
# 0      OR 3802 TUI fly 2023-12-21 22:30:00        236 2023-12-21 23:10:00
# 1    LH 2310 Lufthansa 2023-12-21 22:35:00        339 2023-12-21 23:05:00
# 2          KL 1032 KLM 2023-12-21 22:35:00        344 2023-12-21 23:00:00
# 3   AZ 118 ITA Airways 2023-12-21 22:40:00        346 2023-12-21 23:15:00
# 4          KL 1706 KLM 2023-12-21 23:00:00        316 2023-12-21 23:25:00
# 5           KL 980 KLM 2023-12-21 23:00:00        186 2023-12-21 23:40:00
# 6          KL 1118 KLM 2023-12-21 23:00:00        263 2023-12-21 23:30:00
# 7          KL 1434 KLM 2023-12-21 23:00:00        343 2023-12-21 23:20:00
# 8          KL 1136 KLM 2023-12-21 23:05:00        263 2023-12-21 23:35:00
# 9    HV 5136 Transavia 2023-12-21 23:15:00        339 2023-12-21 23:50:00
# 10   HV 6886 Transavia 2023-12-21 23:15:00        386 2023-12-21 23:45:00
# 11         KL 1082 KLM 2023-12-21 23:20:00        375 2023-12-21 23:55:00
# 12   HV 5358 Transavia 2023-12-21 23:20:00        239 2023-12-22 00:15:00
# 13         KL 1834 KLM 2023-12-21 23:20:00        319 2023-12-22 00:00:00
# 14   HV 6114 Transavia 2023-12-21 23:25:00        300 2023-12-22 00:10:00
# 15         KL 1608 KLM 2023-12-21 23:25:00        309 2023-12-22 00:05:00
# 16   HV 5806 Transavia 2023-12-21 23:30:00        310 2023-12-22 00:20:00
# 17   HV 6902 Transavia 2023-12-21 23:40:00        316 2023-12-22 00:25:00
# 18   HV 5666 Transavia 2023-12-21 23:50:00        347 2023-12-22 00:30:00
# 19   HV 5218 Transavia 2023-12-21 23:55:00        304 2023-12-22 00:35:00
#
#          util  time_dff
# 0  -27.708850      40.0
# 1  -24.492023      30.0
# 2  -20.523346      25.0
# 3  -28.795046      35.0
# 4  -19.850623      25.0
# 5  -24.217852      40.0
# 6  -21.945770      30.0
# 7  -16.400726      20.0
# 8  -21.945770      30.0
# 9  -28.574027      35.0
# 10 -25.645554      30.0
# 11 -29.632576      35.0
# 12 -38.351283      55.0
# 13 -31.883659      40.0
# 14 -34.959143      45.0
# 15 -31.467525      40.0
# 16 -39.387601      50.0
# 17 -35.731121      45.0
# 18 -32.943992      40.0
# 19 -31.251525      40.0

# %% [markdown]
# Comparing the result, the first one with discount rate for flights that were originally scheduled for later, and the second one with any discount rate, the one with discount rate are more likely to prioritise earlier flights.

# %% [markdown]
# ## Test 7
# In the previous testing, we did not observe any of the flights being diverted. By assumption of our cases, we state that if flights are overdue for longer than a defined period, the flight should be diverted, for example, due to the insufficiency of fuel for a flight to stay on hold for longer than 120 minutes.
#
# The below set up is just to search for a problem set up such that we can verify the problem will sometimes divert flight.

# %%
def util_f(delay, pass_load):
    scaled_pass_load = pass_load/200
    util = delay * (np.exp(scaled_pass_load) - 1) / np.exp(scaled_pass_load)
    return util

# %%
# subset new df
df_subset_7 = df.tail(40).reset_index(drop = True)
# Instatiate and return the result
AMS21_7 = reschedule_custom_u_dis(df_subset_7, util_f = util_f, n_runway = 2,
                                  max_delay=120, disruption_dur= 110, dis_rate = 1.01,
                                  divert_penalty= 1.01)
AMS21_7.solve(best_first_graph_search)
AMS21_7_result = AMS21_7.display()
# Out:
# The airport resumed service at 23:35
# 2 flights being diverted

# %%
AMS21_7_result
# Out:
#                                    code            time_sch  pass_load  \
# 0                           KL 1800 KLM 2023-12-21 21:45:00        204
# 1                           KL 1246 KLM 2023-12-21 21:50:00        254
# 2                       VY 8311 Vueling 2023-12-21 21:55:00        208
# 3                       OR 1572 TUI fly 2023-12-21 21:55:00        340
# 4               EJU 7858 easyJet Europe 2023-12-21 22:00:00        250
# 5               EJU 7846 easyJet Europe 2023-12-21 22:00:00        244
# 6                     LH 1002 Lufthansa 2023-12-21 22:05:00        291
# 7                BA 444 British Airways 2023-12-21 22:05:00        372
# 8               EJU 7930 easyJet Europe 2023-12-21 22:10:00        292
# 9               EJU 7832 easyJet Europe 2023-12-21 22:10:00        252
# 10              EJU 7864 easyJet Europe 2023-12-21 22:10:00        216
# 11                           KL 998 KLM 2023-12-21 22:15:00        314
# 12                    HV 6868 Transavia 2023-12-21 22:15:00        323
# 13                    HV 6728 Transavia 2023-12-21 22:15:00        307
# 14              EJU 8675 easyJet Europe 2023-12-21 22:15:00        379
# 15             OS 377 Austrian Airlines 2023-12-21 22:15:00        291
# 16                          KL 1676 KLM 2023-12-21 22:15:00        282
# 17              TP 674 TAP Air Portugal 2023-12-21 22:20:00        316
# 18  LX 736 Swiss International Airlines 2023-12-21 22:25:00        329
# 19           LO 269 LOT Polish Airlines 2023-12-21 22:30:00        392
# 20                      OR 3802 TUI fly 2023-12-21 22:30:00        236
# 21                    LH 2310 Lufthansa 2023-12-21 22:35:00        339
# 22                          KL 1032 KLM 2023-12-21 22:35:00        344
# 23                   AZ 118 ITA Airways 2023-12-21 22:40:00        346
# 24                          KL 1706 KLM 2023-12-21 23:00:00        316
# 25                           KL 980 KLM 2023-12-21 23:00:00        186
# 26                          KL 1118 KLM 2023-12-21 23:00:00        263
# 27                          KL 1434 KLM 2023-12-21 23:00:00        343
# 28                          KL 1136 KLM 2023-12-21 23:05:00        263
# 29                    HV 5136 Transavia 2023-12-21 23:15:00        339
# 30                    HV 6886 Transavia 2023-12-21 23:15:00        386
# 31                          KL 1082 KLM 2023-12-21 23:20:00        375
# 32                    HV 5358 Transavia 2023-12-21 23:20:00        239
# 33                          KL 1834 KLM 2023-12-21 23:20:00        319
# 34                    HV 6114 Transavia 2023-12-21 23:25:00        300
# 35                          KL 1608 KLM 2023-12-21 23:25:00        309
# 36                    HV 5806 Transavia 2023-12-21 23:30:00        310
# 37                    HV 6902 Transavia 2023-12-21 23:40:00        316
# 38                    HV 5666 Transavia 2023-12-21 23:50:00        347
# 39                    HV 5218 Transavia 2023-12-21 23:55:00        304
#
#               time_new        util  time_dff
# 0  2023-12-21 23:40:00  -91.525926     115.0
# 1  2023-12-21 23:35:00  -93.061218     105.0
# 2  1970-01-01 00:00:00  -95.615669  diverted
# 3  2023-12-21 23:35:00  -99.728142     100.0
# 4  2023-12-21 23:45:00  -90.507894     105.0
# 5  2023-12-21 23:50:00  -93.658262     110.0
# 6  2023-12-21 23:45:00  -91.696622     100.0
# 7  2023-12-21 23:40:00  -95.944305      95.0
# 8  2023-12-21 23:55:00  -95.472928     105.0
# 9  2023-12-22 00:10:00 -101.804605     120.0
# 10 1970-01-01 00:00:00  -94.792937  diverted
# 11 2023-12-22 00:00:00  -97.506077     105.0
# 12 2023-12-21 23:55:00  -93.936369     100.0
# 13 2023-12-22 00:00:00  -96.593690     105.0
# 14 2023-12-21 23:50:00  -94.650265      95.0
# 15 2023-12-22 00:05:00  -98.878820     110.0
# 16 2023-12-22 00:05:00  -97.493159     110.0
# 17 2023-12-22 00:10:00 -101.402209     110.0
# 18 2023-12-22 00:15:00 -102.037237     110.0
# 19 2023-12-22 00:15:00 -102.667242     105.0
# 20 2023-12-22 00:25:00  -90.663862     115.0
# 21 2023-12-22 00:20:00  -96.593786     105.0
# 22 2023-12-22 00:20:00  -97.130125     105.0
# 23 2023-12-22 00:25:00  -96.377163     105.0
# 24 2023-12-22 00:30:00  -76.617195      90.0
# 25 2023-12-22 00:50:00  -71.403241     110.0
# 26 2023-12-22 00:35:00  -74.507981      95.0
# 27 2023-12-22 00:30:00  -79.127090      90.0
# 28 2023-12-22 00:40:00  -73.770278      95.0
# 29 2023-12-22 00:40:00  -72.211743      85.0
# 30 2023-12-22 00:35:00  -71.164977      80.0
# 31 2023-12-22 00:45:00  -74.145434      85.0
# 32 2023-12-22 00:55:00  -68.250357      95.0
# 33 2023-12-22 00:45:00  -69.805752      85.0
# 34 2023-12-22 00:55:00  -71.323643      90.0
# 35 2023-12-22 00:50:00  -68.212548      85.0
# 36 2023-12-22 01:00:00  -71.606659      90.0
# 37 2023-12-22 01:00:00  -62.893062      80.0
# 38 2023-12-22 01:05:00  -59.953339      75.0
# 39 2023-12-22 01:05:00  -52.556176      70.0

# %% [markdown]
# ## Heuristic Search

# %% [markdown]
# Recall that uninformed searches (breadth-first search and uniform cost search) computes the utility (or cost) from the initial state to the current exploring node. The heuristic function, on the other hand, computes the cost from the current exploring node to a terminal node.
#
# With the rescheulding problem, most (if not all) of the terminal states are associate to nodes of the same depth. However, under the uniform-cost search problem, there is the likelyhood that within the frontier there are nodes of different depth. As such, it will still be useful to consider the distance (in tree depth) from the terminal states as part of the heuristic function.
#
# Recalled that an A* search is the same with  Uniform-cost search in terms of the structure. The only thing differing is the utility function that determines which node to explore next. In an A* search, it is evaluated by:
# $$f(n) = g(n) +h(n)$$
#
# The uniform-cost search algorithm is by design taking $g(n)$ as a function of time delay, taking a range of $(-\infty,0]$. Intuitivity, it expands the node that has the **highest utility** (i.e. lowest maximum value of the cost). Similarly, we could define **h(n)** such that the algorithm expands the node with the high "expected" utility. Alternatively, this could be understood as closest to a terminal state.
#
# Recall that the priority queue order is determined by path_cost attribute of the node. Hence, we need to overwrite the `utility` method of the problem class.

# %% [markdown]
# One simple admissble heuristic is simply the number of flights that has been assigned a slot.

# %%
class reschedule_heuristic(reschedule_custom_u_dis):
    def __init__(self, df,util_f, n_runway = 1, disruption_dur = 60,
                timeslot_dur = 5, max_delay = 120, divert_penalty = 1, dis_rate = 1.01,
                h_weight = 1):
        super().__init__(df, util_f,n_runway , disruption_dur,
                timeslot_dur, max_delay, divert_penalty,dis_rate)
        self.h_weight = h_weight

    def utility(self, state:pd.DataFrame):
        """Compute aggregate utility of a given state"""
        agg_cost = state['util'].sum()
        # compute heuristic
        heuristic = len(state.index)
        return agg_cost + self.h_weight * heuristic

# %%
def util_f(delay, pass_load):
    scaled_pass_load = pass_load/200
    util = delay * (np.exp(scaled_pass_load) - 1) / np.exp(scaled_pass_load)
    return util

# %% [markdown]
# By considering the heuristic function, an A-star search should yield the cost-optimal result. In order to check if the result is cost optimal, we will use the result that was generated in test 4.
# Recall that in the fourth test of rescheduling 6 flights, we identified a solution with the highest utility of $-56.71$.breadth-first search. By unifrom cost search, the solution returned has a utility of $-57.31$. We will replicate the problem set up again, but this time, including the heuristic dunction in determining the order of node to explore.

# %%
# subset
df_subset_4 = df.tail(6).reset_index(drop = True)
# instantiate the problem
AMS21_n6_8 = reschedule_heuristic(df_subset_4,util_f, n_runway = 1,max_delay=120, disruption_dur= 15,
                                  dis_rate= 1)
# solve the problem
AMS21_n6_8.solve(best_first_graph_search)
# the breadth first search returns a list of solution(s)
sol_8 = AMS21_n6_8.solution
sol_8
# Out:
# The airport resumed service at 23:40
#                            time_new       util
# KL 1608 KLM        2023 12 21 23:40 -11.800322
# HV 6114 Transavia  2023 12 21 23:45 -15.537397
# HV 5806 Transavia  2023 12 21 23:50 -15.755041
# HV 6902 Transavia  2023 12 21 23:55 -11.910374
# HV 5666 Transavia  2023 12 22 00:00  -8.235998
# HV 5218 Transavia  2023 12 22 00:05  -7.812881

# %%
sol_8['util'].sum()
# Out:
# -71.052011906694

# %% [markdown]
# Comparing the solution of the A* search with other search, it seems that the A-star seach algorithm does not return the optimal solution. Note that in the redblob game example and the route search problem, there is only one terminal state. On the contrary, the rescheduling problem has more than one solution. Therefore, the heuristic function cannot effectively encourage the what was effectively a uniform-cost search agent to explore other shallow nodes, which has a lower utility.

# %% [markdown]
# # CSP: Min-conflicts Local Search

# %% [markdown]
# The `FlightSchedulerCSP` Class
# - Initializes the flight scheduler model with the necessary parameters and calls the `CSP` class constructor.
# - Parameters:
#   - `flights_df`: DataFrame containing flight details.
#   - `disruption_level`: Minutes of delay caused by a disruption.
#   - `num_runways`: Number of available runways.
#   - `neighbor_window`: The time window in minutes to consider flights as neighbors.
#   - `time_slot`: The interval in minutes for generating time slots.
# - It also initializes a special 'diverted' slot for handling unscheduled flights.
#
# Min-Conflicts Search Functions
#
# `min_conflicts` Function
# - A hill-climbing algorithm to solve the CSP. It iteratively tries to reduce the number of conflicts in the current assignment.
# - Includes a conflict resolution parameter ('early', 'force', 'divert').
# - Returns the final assignment or diverts unresolved flights.
#
# `min_conflicts_value` Function
# - Chooses the best value (time slot) for a variable (flight) that results in the least number of conflicts.
# - If there's a tie, the earliest time slot is selected. If no valid time slot is found, it resorts to the diverted slot.
#
# Summary
# - This custom CSP model is designed to handle a flight scheduling problem.
# - It manages constraints like runway capacity and disruption times, and it includes a mechanism to handle flights that can't be scheduled within the given constraints by diverting them.
# - The min-conflicts search algorithm is used to find a near-optimal solution, considering the constraints and the nature of the problem.
# - The model is flexible enough to handle various numbers of flights, runways, and disruption scenarios.

# %%
from csp_problem import *

# %%
df['delay'] = (df.time_act - df.time_sch).dt.seconds / 60 # in minutes
df_subset_6 = df.tail(20).reset_index(drop = True)

# %%
# %pip install Jinja2

# %%
sample = df_subset_6.copy()
flight_schedule_csp = FlightSchedulerCSP(sample, disruption_level=30, num_runways=1, neighbor_window=10, time_slot=5)
solutions = min_conflicts(flight_schedule_csp, resolve_strategy="early")

sample['new_sch'] = solutions.values()
sample['new_delay'] = (sample.new_sch - sample.time_sch).dt.seconds / 60 # in minutes

print(f"Total new delay: {sample.new_delay.sum()}")
print(f"Total diverted flights: {len(sample[sample.new_sch == flight_schedule_csp.diverted_slot])}")
sample[["code", "time_sch", "pass_load", "new_sch", "delay", "new_delay"]].head(15)
# Out:
# Total new delay: 745.0
# Total diverted flights: 0
#                   code            time_sch  pass_load             new_sch  \
# 0      OR 3802 TUI fly 2023-12-21 22:30:00        236 2023-12-21 23:00:00
# 1    LH 2310 Lufthansa 2023-12-21 22:35:00        339 2023-12-21 23:05:00
# 2          KL 1032 KLM 2023-12-21 22:35:00        344 2023-12-21 23:10:00
# 3   AZ 118 ITA Airways 2023-12-21 22:40:00        346 2023-12-21 23:15:00
# 4          KL 1706 KLM 2023-12-21 23:00:00        316 2023-12-21 23:30:00
# 5           KL 980 KLM 2023-12-21 23:00:00        186 2023-12-21 23:35:00
# 6          KL 1118 KLM 2023-12-21 23:00:00        263 2023-12-21 23:40:00
# 7          KL 1434 KLM 2023-12-21 23:00:00        343 2023-12-21 23:45:00
# 8          KL 1136 KLM 2023-12-21 23:05:00        263 2023-12-21 23:50:00
# 9    HV 5136 Transavia 2023-12-21 23:15:00        339 2023-12-21 23:45:00
# 10   HV 6886 Transavia 2023-12-21 23:15:00        386 2023-12-21 23:55:00
# 11         KL 1082 KLM 2023-12-21 23:20:00        375 2023-12-21 23:50:00
# 12   HV 5358 Transavia 2023-12-21 23:20:00        239 2023-12-22 00:00:00
# 13         KL 1834 KLM 2023-12-21 23:20:00        319 2023-12-22 00:05:00
# 14   HV 6114 Transavia 2023-12-21 23:25:00        300 2023-12-22 00:10:00
#
#     delay  new_delay
# 0     0.0       30.0
# 1     0.0       30.0
# 2    62.0       35.0
# 3   150.0       35.0
# 4     0.0       30.0
# 5     0.0       35.0
# 6    52.0       40.0
# 7    54.0       45.0
# 8     0.0       45.0
# 9    76.0       30.0
# 10   53.0       40.0
# 11    0.0       30.0
# 12   50.0       40.0
# 13   58.0       45.0
# 14   77.0       45.0

# %%
data = sample[["code", "time_sch", "pass_load", "new_sch", "delay", "new_delay"]].head(15)
col_names = ["FlightID", "Departure", "Passengers", "NewDep", "Delay", "EstDelay"]
data.columns = col_names

styler = data.style
styler = (
    styler.format(subset="Delay", precision=1)
       .format(subset="EstDelay", precision=1)
       .hide(level=0, axis=0)
       )

table = styler.to_latex(
    caption="Estimated Schedule",
    position_float="centering",
    hrules=True
)

print(table)
# Out:
# \begin{table}
# \centering
# \caption{Estimated Schedule}
# \begin{tabular}{llrlrr}
# \toprule
# FlightID & Departure & Passengers & NewDep & Delay & EstDelay \\
# \midrule
# OR 3802 TUI fly & 2023-12-21 22:30:00 & 236 & 2023-12-21 23:00:00 & 0.0 & 30.0 \\
# LH 2310 Lufthansa & 2023-12-21 22:35:00 & 339 & 2023-12-21 23:05:00 & 0.0 & 30.0 \\
# KL 1032 KLM & 2023-12-21 22:35:00 & 344 & 2023-12-21 23:10:00 & 62.0 & 35.0 \\
# AZ 118 ITA Airways & 2023-12-21 22:40:00 & 346 & 2023-12-21 23:15:00 & 150.0 & 35.0 \\
# KL 1706 KLM & 2023-12-21 23:00:00 & 316 & 2023-12-21 23:30:00 & 0.0 & 30.0 \\
# KL 980 KLM & 2023-12-21 23:00:00 & 186 & 2023-12-21 23:35:00 & 0.0 & 35.0 \\
# KL 1118 KLM & 2023-12-21 23:00:00 & 263 & 2023-12-21 23:40:00 & 52.0 & 40.0 \\
# KL 1434 KLM & 2023-12-21 23:00:00 & 343 & 2023-12-21 23:45:00 & 54.0 & 45.0 \\
# KL 1136 KLM & 2023-12-21 23:05:00 & 263 & 2023-12-21 23:50:00 & 0.0 & 45.0 \\
# HV 5136 Transavia & 2023-12-21 23:15:00 & 339 & 2023-12-21 23:45:00 & 76.0 & 30.0 \\
# HV 6886 Transavia & 2023-12-21 23:15:00 & 386 & 2023-12-21 23:55:00 & 53.0 & 40.0 \\
# KL 1082 KLM & 2023-12-21 23:20:00 & 375 & 2023-12-21 23:50:00 & 0.0 & 30.0 \\
# HV 5358 Transavia & 2023-12-21 23:20:00 & 239 & 2023-12-22 00:00:00 & 50.0 & 40.0 \\
# KL 1834 KLM & 2023-12-21 23:20:00 & 319 & 2023-12-22 00:05:00 & 58.0 & 45.0 \\
# HV 6114 Transavia & 2023-12-21 23:25:00 & 300 & 2023-12-22 00:10:00 & 77.0 & 45.0 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ## Comparing to Test 6

# %%
# subset
df_subset_6 = df.tail(20).reset_index(drop = True)
# Instatiate and return the result
AMS21_n20_6 = reschedule_custom_u(df_subset_6, util_f, n_runway = 1,
                                  max_delay=90, disruption_dur= 30)
AMS21_n20_6.solve(best_first_graph_search)
AMS21_n20_6_result = AMS21_n20_6.display()

print(f"Total new delay: {AMS21_n20_6_result.time_dff.sum()}")
AMS21_n20_6_result
# Out:
# The airport resumed service at 23:00
# 0 flights being diverted
# Total new delay: 730.0
#                   code            time_sch  pass_load            time_new  \
# 0      OR 3802 TUI fly 2023-12-21 22:30:00        236 2023-12-21 23:10:00
# 1    LH 2310 Lufthansa 2023-12-21 22:35:00        339 2023-12-21 23:05:00
# 2          KL 1032 KLM 2023-12-21 22:35:00        344 2023-12-21 23:00:00
# 3   AZ 118 ITA Airways 2023-12-21 22:40:00        346 2023-12-21 23:15:00
# 4          KL 1706 KLM 2023-12-21 23:00:00        316 2023-12-21 23:25:00
# 5           KL 980 KLM 2023-12-21 23:00:00        186 2023-12-21 23:40:00
# 6          KL 1118 KLM 2023-12-21 23:00:00        263 2023-12-21 23:30:00
# 7          KL 1434 KLM 2023-12-21 23:00:00        343 2023-12-21 23:20:00
# 8          KL 1136 KLM 2023-12-21 23:05:00        263 2023-12-21 23:35:00
# 9    HV 5136 Transavia 2023-12-21 23:15:00        339 2023-12-21 23:50:00
# 10   HV 6886 Transavia 2023-12-21 23:15:00        386 2023-12-21 23:45:00
# 11         KL 1082 KLM 2023-12-21 23:20:00        375 2023-12-21 23:55:00
# 12   HV 5358 Transavia 2023-12-21 23:20:00        239 2023-12-22 00:15:00
# 13         KL 1834 KLM 2023-12-21 23:20:00        319 2023-12-22 00:00:00
# 14   HV 6114 Transavia 2023-12-21 23:25:00        300 2023-12-22 00:10:00
# 15         KL 1608 KLM 2023-12-21 23:25:00        309 2023-12-22 00:05:00
# 16   HV 5806 Transavia 2023-12-21 23:30:00        310 2023-12-22 00:20:00
# 17   HV 6902 Transavia 2023-12-21 23:40:00        316 2023-12-22 00:25:00
# 18   HV 5666 Transavia 2023-12-21 23:50:00        347 2023-12-22 00:30:00
# 19   HV 5218 Transavia 2023-12-21 23:55:00        304 2023-12-22 00:35:00
#
#          util  time_dff
# 0  -27.708850      40.0
# 1  -24.492023      30.0
# 2  -20.523346      25.0
# 3  -28.795046      35.0
# 4  -19.850623      25.0
# 5  -24.217852      40.0
# 6  -21.945770      30.0
# 7  -16.400726      20.0
# 8  -21.945770      30.0
# 9  -28.574027      35.0
# 10 -25.645554      30.0
# 11 -29.632576      35.0
# 12 -38.351283      55.0
# 13 -31.883659      40.0
# 14 -34.959143      45.0
# 15 -31.467525      40.0
# 16 -39.387601      50.0
# 17 -35.731121      45.0
# 18 -32.943992      40.0
# 19 -31.251525      40.0

# %%
test = AMS21_n20_6_result.copy()
test['csp_sch'] = sample.new_sch
test['csp_delay'] = sample.new_delay
test['delay_diff'] = test.time_dff - test.csp_delay
print(f"Total delay diff: {test.delay_diff.sum()}")
test
# Out:
# Total delay diff: -15.0
#                   code            time_sch  pass_load            time_new  \
# 0      OR 3802 TUI fly 2023-12-21 22:30:00        236 2023-12-21 23:10:00
# 1    LH 2310 Lufthansa 2023-12-21 22:35:00        339 2023-12-21 23:05:00
# 2          KL 1032 KLM 2023-12-21 22:35:00        344 2023-12-21 23:00:00
# 3   AZ 118 ITA Airways 2023-12-21 22:40:00        346 2023-12-21 23:15:00
# 4          KL 1706 KLM 2023-12-21 23:00:00        316 2023-12-21 23:25:00
# 5           KL 980 KLM 2023-12-21 23:00:00        186 2023-12-21 23:40:00
# 6          KL 1118 KLM 2023-12-21 23:00:00        263 2023-12-21 23:30:00
# 7          KL 1434 KLM 2023-12-21 23:00:00        343 2023-12-21 23:20:00
# 8          KL 1136 KLM 2023-12-21 23:05:00        263 2023-12-21 23:35:00
# 9    HV 5136 Transavia 2023-12-21 23:15:00        339 2023-12-21 23:50:00
# 10   HV 6886 Transavia 2023-12-21 23:15:00        386 2023-12-21 23:45:00
# 11         KL 1082 KLM 2023-12-21 23:20:00        375 2023-12-21 23:55:00
# 12   HV 5358 Transavia 2023-12-21 23:20:00        239 2023-12-22 00:15:00
# 13         KL 1834 KLM 2023-12-21 23:20:00        319 2023-12-22 00:00:00
# 14   HV 6114 Transavia 2023-12-21 23:25:00        300 2023-12-22 00:10:00
# 15         KL 1608 KLM 2023-12-21 23:25:00        309 2023-12-22 00:05:00
# 16   HV 5806 Transavia 2023-12-21 23:30:00        310 2023-12-22 00:20:00
# 17   HV 6902 Transavia 2023-12-21 23:40:00        316 2023-12-22 00:25:00
# 18   HV 5666 Transavia 2023-12-21 23:50:00        347 2023-12-22 00:30:00
# 19   HV 5218 Transavia 2023-12-21 23:55:00        304 2023-12-22 00:35:00
#
#          util  time_dff             csp_sch  csp_delay  delay_diff
# 0  -27.708850      40.0 2023-12-21 23:00:00       30.0        10.0
# 1  -24.492023      30.0 2023-12-21 23:05:00       30.0         0.0
# 2  -20.523346      25.0 2023-12-21 23:10:00       35.0       -10.0
# 3  -28.795046      35.0 2023-12-21 23:15:00       35.0         0.0
# 4  -19.850623      25.0 2023-12-21 23:30:00       30.0        -5.0
# 5  -24.217852      40.0 2023-12-21 23:35:00       35.0         5.0
# 6  -21.945770      30.0 2023-12-21 23:40:00       40.0       -10.0
# 7  -16.400726      20.0 2023-12-21 23:45:00       45.0       -25.0
# 8  -21.945770      30.0 2023-12-21 23:50:00       45.0       -15.0
# 9  -28.574027      35.0 2023-12-21 23:45:00       30.0         5.0
# 10 -25.645554      30.0 2023-12-21 23:55:00       40.0       -10.0
# 11 -29.632576      35.0 2023-12-21 23:50:00       30.0         5.0
# 12 -38.351283      55.0 2023-12-22 00:00:00       40.0        15.0
# 13 -31.883659      40.0 2023-12-22 00:05:00       45.0        -5.0
# 14 -34.959143      45.0 2023-12-22 00:10:00       45.0         0.0
# 15 -31.467525      40.0 2023-12-22 00:15:00       50.0       -10.0
# 16 -39.387601      50.0 2023-12-22 00:20:00       50.0         0.0
# 17 -35.731121      45.0 2023-12-22 00:10:00       30.0        15.0
# 18 -32.943992      40.0 2023-12-22 00:20:00       30.0        10.0
# 19 -31.251525      40.0 2023-12-22 00:25:00       30.0        10.0

# %%
data = test[["code", "time_sch", "csp_sch", "time_dff", "csp_delay"]].head(5)
col_names = ["FlightID", "Departure", "Est. Departure", "TreeDelay", "CSPDelay"]
data.columns = col_names

styler = data.style
styler = (
    styler.format(subset="TreeDelay", precision=1)
       .format(subset="CSPDelay", precision=1)
       .hide(level=0, axis=0)
       )

table = styler.to_latex(
    caption="Estimated Schedule",
    position_float="centering",
    hrules=True
)

print(table)
# Out:
# \begin{table}
# \centering
# \caption{Estimated Schedule}
# \begin{tabular}{lllrr}
# \toprule
# FlightID & Departure & Est. Departure & TreeDelay & CSPDelay \\
# \midrule
# OR 3802 TUI fly & 2023-12-21 22:30:00 & 2023-12-21 23:00:00 & 40.0 & 30.0 \\
# LH 2310 Lufthansa & 2023-12-21 22:35:00 & 2023-12-21 23:05:00 & 30.0 & 30.0 \\
# KL 1032 KLM & 2023-12-21 22:35:00 & 2023-12-21 23:10:00 & 25.0 & 35.0 \\
# AZ 118 ITA Airways & 2023-12-21 22:40:00 & 2023-12-21 23:15:00 & 35.0 & 35.0 \\
# KL 1706 KLM & 2023-12-21 23:00:00 & 2023-12-21 23:30:00 & 25.0 & 30.0 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ## Analysis
#
# The modifications made to the FlightSchedulerCSP class, including the addition of a diverted_slot and adjustments to time slot generation and constraints, provides in a custom flight scheduling CSP model. Let's summarize the key aspects of this experiment and compare it with tree-based search algorithms using utility functions.
# Summary of the Experiment:
#
# - Custom Time Slot Frequency: The time_slot parameter allows you to set the frequency of time slots. This change enables more precise scheduling.
#
# - Extended Time Slot Range: The time slots are generated up to the last possible time considering the disruption level and the time slot interval. This ensures a comprehensive range for rescheduling flights.
#
# - Diverted Slot for Unsolvable Conflicts: A diverted_slot set to a future date acts as a fallback for flights that cannot be accommodated. This helps in managing unsolvable conflicts.
#
# - Constraints Adjustments: The constraint function now accounts for the number of flights scheduled at a time and compares it with the available runway capacity. It also accommodates the diverted slot.
#
# - Handling of Local Minima: The min-conflicts algorithm includes a check to prevent getting stuck in local minima, ensuring that the algorithm provides a solution.
#
# - Selection of Earliest Time Slot: The algorithm selects the earliest time slot that minimizes conflicts, or if not feasible, assigns the flight to the diverted slot.
#
# Pros of the CSP Implementation:
#
# - Flexibility in Scheduling: Customizable time slot intervals offer more control over the scheduling process.
# - Efficient Handling of Conflicts: The ability to divert flights provides a clear solution for otherwise unsolvable scheduling conflicts.
# - Adaptability to Various Scenarios: The CSP model can adapt to different runway capacities and disruption levels.
# - Prevention of Stagnation: Safeguards against local minima ensure the algorithm always returns a result.
#
# Cons of the CSP Implementation:
#
# - Increased Complexity: The added features and parameters make the model more complex and potentially harder to manage.
# - Risk of Suboptimal Solutions: The use of a diverted slot, while practical, might lead to suboptimal scheduling outcomes.
# - Dependence on Parameter Settings: The effectiveness of the model heavily relies on the chosen values for parameters like time_slot and neighbor_window.
#
# Comparison with Tree-Based Search Using Utility Functions:
#
# - CSP vs. Tree-Based Search: CSP focuses on finding a solution that satisfies all constraints, while tree-based search algorithms aim to find an optimal solution based on a utility function.
# - Handling of Conflicts: CSPs, especially with the addition of the diverted slot, can handle conflicts more flexibly compared to tree-based searches, which might require more complex utility functions to manage similar scenarios.
# - Scalability and Performance: Tree-based searches can be more computationally intensive, especially for large problem spaces, whereas CSPs with the min-conflicts heuristic can be more efficient in finding satisfactory solutions.
# - Optimality of Solutions: Tree-based searches are more likely to find the most optimal solution, but at the cost of increased computational effort. In contrast, CSPs may quickly find a satisfactory solution but not necessarily the most optimal one.
#
# In summary, the CSP model is capable to handle large state spaces quickly. While it offers a practical approach to managing unsolvable conflicts, it may not always provide the most optimal scheduling compared to tree-based search algorithms focused on maximizing a utility function.
