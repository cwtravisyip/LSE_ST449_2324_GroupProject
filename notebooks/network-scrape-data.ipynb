# %%
# !pip install networkx
# !pip install matplotlib

# %%
import os
import time
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/19DEC2023_AMS.csv")

# %%
df
# Out:
#      time_sch time_act               code                       dest  \
# 0       06:00    06:00  HV 5315 Transavia              Larnaca (LCA)
# 1       06:30    06:30  HV 6411 Transavia               Naples (NAP)
# 2       06:30    07:04  HV 6901 Transavia  Dubai International (DXB)
# 3       06:40    06:55  HV 5951 Transavia               Lisbon (LIS)
# 4       06:40    06:40  HV 6331 Transavia             Valencia (VLC)
# ...       ...      ...                ...                        ...
# 1142    23:25    23:25  HV 6118 Transavia                  Amsterdam
# 1143    23:25    23:25        KL 1608 KLM                  Amsterdam
# 1144    23:40    23:40  HV 6902 Transavia                  Amsterdam
# 1145    23:45    23:45  HV 5356 Transavia                  Amsterdam
# 1146    23:50    23:50  HV 6120 Transavia                  Amsterdam
#
#                  stat                       orig
# 0            DEPARTED                  Amsterdam
# 1            DEPARTED                  Amsterdam
# 2            DEPARTED                  Amsterdam
# 3            DEPARTED                  Amsterdam
# 4            DEPARTED                  Amsterdam
# ...               ...                        ...
# 1142  BAGGAGE HANDLED               Malaga (AGP)
# 1143  BAGGAGE HANDLED                 Rome (FCO)
# 1144  BAGGAGE HANDLED  Dubai International (DXB)
# 1145  BAGGAGE HANDLED                 Faro (FAO)
# 1146  BAGGAGE HANDLED               Malaga (AGP)
#
# [1147 rows x 6 columns]

# %%
G = nx.DiGraph()

# Adding nodes and edges based on the flight data
for index, row in df.iterrows():
    G.add_edge(row['orig'], row['dest'], departure=row['time_sch'])

# %%
plt.figure(figsize=(12, 8))
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, font_size=10)
plt.title("Flight Network Graph")
plt.show()
